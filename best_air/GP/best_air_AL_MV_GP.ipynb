# %%
import requests
import numpy as np
import casadi as ca
import matplotlib.pyplot as plt
import os
from IPython.display import clear_output
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import gpytorch
from common import get_data, to_tensor
import constant as const
from call_GP import train_GP, ExactGPModel, evaluate_gp, call_model, cal_pos

url = "http://127.0.0.1:80"
testcase = 'bestest_air'
testid = \
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
save_dir = 'results'
os.makedirs(save_dir, exist_ok=True)

print("done")
# Out:
# Using: cuda
# done

# %%
testid = \
requests.post('{0}/testcases/{1}/select'.format(url,testcase)).json()['testid']
name = requests.get('{0}/name/{1}'.format(url, testid)).json()['payload']
print(name)

version = requests.get('{0}/version'.format(url)).json()['payload']
print(version)
inputs = requests.get('{0}/inputs/{1}'.format(url, testid)).json()['payload']
print('TEST CASE INPUTS ---------------------------------------------')
print(inputs.keys())

print('TEST CASE MEASUREMENTS ---------------------------------------')
measurements = requests.get('{0}/measurements/{1}'.format(url, testid)).json()['payload']
# Out:
# {'name': 'bestest_air'}
# {'version': '0.8.0'}
# TEST CASE INPUTS ---------------------------------------------
# dict_keys(['con_oveTSetCoo_activate', 'con_oveTSetCoo_u', 'con_oveTSetHea_activate', 'con_oveTSetHea_u', 'fcu_oveFan_activate', 'fcu_oveFan_u', 'fcu_oveTSup_activate', 'fcu_oveTSup_u'])
# TEST CASE MEASUREMENTS ---------------------------------------

# %%
step = const.step

data = pd.read_csv(f'processed_uniform_low_step_5m_data.csv')
data_test = data

data.head()

T_zone = (data['zon_reaTRooAir_y'].values - 273.15) / 30.0
T_sup  = (data['fcu_oveTSup_u'].values - 273.15) / 40.0
fan  = data['fcu_oveFan_u'].values
T_out = (data['zon_weaSta_reaWeaTDryBul_y'].values - 273.15) / 10.0


pos_T_zone = T_zone[1:]
cur_T_zone = T_zone[:-1]
cur_T_sup = T_sup[:-1]
cur_fan = fan[:-1]
cur_T_out = T_out[:-1]


def data_split(Ns, Ne, x1, x2, x3, x4, x5):
    return (to_tensor(x1[Ns:Ne]).view(-1,1), to_tensor(x2[Ns:Ne]).view(-1,1),
            to_tensor(x3[Ns:Ne]).view(-1,1), to_tensor(x4[Ns:Ne]).view(-1,1), to_tensor(x5[Ns:Ne]).view(-1,1))


Ns_tr, Ne_tr = const.Ns_tr, const.Ne_tr  
Ns_t, Ne_t = const.Ns_t, const.Ne_t 
cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr, pos_T_zone_tr = data_split(Ns_tr, Ne_tr, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)
cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t, pos_T_zone_t = data_split(Ns_t, Ne_t, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)

X_tr = torch.cat((cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr), dim=1)
y_tr = pos_T_zone_tr.squeeze(-1)  
X_t = torch.cat((cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t), dim=1)
y_t = pos_T_zone_t.squeeze(-1)

ramp = const.ramp

# %%
class MPC:
    def __init__(self, X_tr, y_tr, model_path=f'model_MV_GP_{step}m.pth'):
        self.likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)
        self.gp_model = ExactGPModel(X_tr, y_tr, self.likelihood).to(device)
        
        state_dict = torch.load(model_path, map_location=device)
        self.gp_model.load_state_dict(state_dict)
        self.gp_model.eval()

    def cal_var(self, x0, u, x_out):
        x0 = torch.tensor(x0, dtype=torch.float32, device=device).view(1, -1)
        u  = torch.tensor(u,  dtype=torch.float32, device=device).view(1, -1)
        x_out = torch.tensor(x_out, dtype=torch.float32, device=device).view(1, -1)
        xu = torch.cat((x0, u, x_out), dim=1)
        with torch.no_grad(), gpytorch.settings.fast_pred_var():
            pred = self.gp_model(xu)
            var = pred.variance

        return var.item()

    def eval_cost(self, x0, u, x_out):
        return self.cal_var(x0, u, x_out)

    def mpc_grid_search(self, x0, x_out, horizon=1, n_grid=20, u0_1=0.5, u0_2=0.5, plot=True):
        x0 = x0 / 30.0

        u_min_general = np.array([0.3, 0.])
        u_max_general = np.array([1.0, 1.0])

        u_min = np.clip(np.array([u0_1 - ramp, u0_2 - ramp]), u_min_general, u_max_general)
        u_max = np.clip(np.array([u0_1 + ramp, u0_2 + ramp]), u_min_general, u_max_general)

        u1_vals = np.linspace(u_min[0], u_max[0], n_grid)
        u2_vals = np.linspace(u_min[1], u_max[1], n_grid)



        N = n_grid * n_grid
        U1_g, U2_g = np.meshgrid(u1_vals, u2_vals, indexing="ij")
        u_batch  = torch.tensor(np.stack([U1_g.ravel(), U2_g.ravel()], axis=1),
                                dtype=torch.float32, device=device)
        x0_t    = torch.full((N, 1), x0,    dtype=torch.float32, device=device)
        x_out_t = torch.full((N, 1), x_out, dtype=torch.float32, device=device)
        xu = torch.cat((x0_t, u_batch, x_out_t), dim=1)

        with torch.no_grad(), gpytorch.settings.fast_pred_var():
            cost_flat = self.gp_model(xu).variance

        cost_grid = cost_flat.cpu().numpy().reshape(n_grid, n_grid)

        valid = np.ones((n_grid, n_grid), dtype=bool)
        valid[u1_vals == u0_1, :] = False
        valid[:, u2_vals == u0_2] = False
        costs_valid = np.where(valid, cost_grid, -np.inf)
        best_idx = np.argmax(costs_valid)
        best_i, best_j = np.unravel_index(best_idx, (n_grid, n_grid))
        best_cost = costs_valid[best_i, best_j]
        best_u    = np.array([u1_vals[best_i], u2_vals[best_j]])
        
        if plot:
            U1, U2 = np.meshgrid(u1_vals, u2_vals, indexing="ij")
            plt.figure(figsize=(6,5))
            cp = plt.contourf(U1, U2, cost_grid, levels=30, cmap="viridis")
            plt.colorbar(cp, label="Cost (-variance)")
            plt.scatter(best_u[0], best_u[1], c="red", marker="x", s=100)
            plt.xlabel("u1 (supply)")
            plt.ylabel("u2 (airflow)")
            plt.title("Grid Search Cost Landscape")
            plt.show()

        u = {
        'fcu_oveTSup_u': best_u[0] * 40 + 273.15,
        'fcu_oveTSup_activate': 1,
        'fcu_oveFan_u': best_u[1],
        'fcu_oveFan_activate': 1
        }
        return u

# %%
y = requests.put('{0}/scenario/{1}'.format(url, testid), 
                 json={'time_period':'typical_heat_day',
                       'electricity_price':'dynamic'}).json()['payload']['time_period']
requests.put('{0}/step/{1}'.format(url, testid), json={'step':step*60})
start_time_days = y['time']/3600/24
train_GP(X_tr=X_tr, y_tr=y_tr.squeeze(-1), save_path=f'model_MV_GP_{step}m.pth', ori=0)
evaluate_gp(X_tr, y_tr, X_t, y_t, save_path=f'model_MV_GP_{step}m.pth')
# Out:
# tensor(0.4029, device='cuda:0')

# %%
last_change_day = start_time_days
counter = 0
u0_1 = 0.5
u0_2 = 0.5
u = {
        'fcu_oveTSup_u': u0_1 * 40 + 273.15,
        'fcu_oveTSup_activate': 1,
        'fcu_oveFan_u': u0_2,
        'fcu_oveFan_activate': 1
        }

x_ref = 25
simulation_time_days = y['time']/3600/24
print('Simulation time [elapsed days] = {:.2f}'.format((simulation_time_days - start_time_days)))
y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  


ls_rmse = [evaluate_gp(X_tr, y_tr, X_t, y_t, save_path=f'model_MV_GP_{step}m.pth')]
X_tr_new = X_tr
y_tr_new = y_tr
num_count = const.num_count
# Out:
# Simulation time [elapsed days] = 0.00

# %%
while y:
    x0 = y['zon_reaTRooAir_y']-273.15
    x_out = (y['zon_weaSta_reaWeaTDryBul_y']-273.15)/10.0
    mpc_controller = MPC(X_tr_new, y_tr_new, model_path=f'model_MV_GP_{step}m.pth')
    u = mpc_controller.mpc_grid_search(x0=x0, x_out=x_out, horizon=1, u0_1=u0_1, u0_2=u0_2, n_grid=10, plot =False)

    print('-------------------------------------------------------------------')
    print('Step counter =', counter)
    print("Controller output:", u)

    y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  
    counter += 1


    cur = to_tensor(x0).view(-1,1)/30.0
    T_sup_add=  to_tensor((u['fcu_oveTSup_u']-273.15)/40.0).view(-1,1)
    fan_add = to_tensor(u['fcu_oveFan_u']).view(-1,1)
    pos_add = to_tensor(y['zon_reaTRooAir_y']-273.15).view(-1,1)/30.0

    T_out_add = to_tensor((y['zon_weaSta_reaWeaTDryBul_y']-273.15)/10.0).view(-1,1)

    X_tr_n = torch.cat((cur, T_sup_add, fan_add, T_out_add), dim=1)

    y_tr_n = pos_add.squeeze(-1)   

    X_tr_new = torch.cat((X_tr_new, X_tr_n), dim=0)
    y_tr_new = torch.cat((y_tr_new, y_tr_n), dim=0)
    
    if const.count_data == const.number_of_data:
        train_GP(X_tr=X_tr_new, y_tr=y_tr_new, save_path=f'model_MV_GP_{step}m.pth', ori=1)
        print("=======retrain GP model=======")
        const.count_data = 0
    const.count_data += 1
    simulation_time_days = y['time']/3600/24
    print('Simulation time [elapsed days] = {:.2f}'.format((simulation_time_days - start_time_days)))

    u0_1 = (u['fcu_oveTSup_u']-273.15)/40.0
    u0_2 = u['fcu_oveFan_u']

    rmse = evaluate_gp(X_tr_new, y_tr_new, X_t, y_t, save_path=f'model_MV_GP_{step}m.pth')

    ls_rmse.append(rmse)
    if counter > num_count:
        break
# Out:
# -------------------------------------------------------------------
# Step counter = 0
# Controller output: {'fcu_oveTSup_u': np.float64(292.34999999999997), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.52), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.01
# -------------------------------------------------------------------
# Step counter = 1
# Controller output: {'fcu_oveTSup_u': np.float64(291.54999999999995), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.54), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.01
# -------------------------------------------------------------------
# Step counter = 2
# Controller output: {'fcu_oveTSup_u': np.float64(290.74999999999994), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.56), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.01
# -------------------------------------------------------------------
# Step counter = 3
# Controller output: {'fcu_oveTSup_u': np.float64(289.94999999999993), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5800000000000001), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.02
# -------------------------------------------------------------------
# Step counter = 4
# Controller output: {'fcu_oveTSup_u': np.float64(289.1499999999999), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6000000000000001), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.02
# -------------------------------------------------------------------
# Step counter = 5
# Controller output: {'fcu_oveTSup_u': np.float64(288.3499999999999), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6200000000000001), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.02
# -------------------------------------------------------------------
# Step counter = 6
# Controller output: {'fcu_oveTSup_u': np.float64(287.5499999999999), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6400000000000001), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.03
# -------------------------------------------------------------------
# Step counter = 7
# Controller output: {'fcu_oveTSup_u': np.float64(286.7499999999999), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6600000000000001), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.03
# -------------------------------------------------------------------
# Step counter = 8
# Controller output: {'fcu_oveTSup_u': np.float64(285.9499999999999), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6800000000000002), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.03
# -------------------------------------------------------------------
# Step counter = 9
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7000000000000002), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.04
# -------------------------------------------------------------------
# Step counter = 10
# Controller output: {'fcu_oveTSup_u': np.float64(285.2388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7200000000000002), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.04
# -------------------------------------------------------------------
# Step counter = 11
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7400000000000002), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.05
# -------------------------------------------------------------------
# Step counter = 12
# Controller output: {'fcu_oveTSup_u': np.float64(285.2388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7600000000000002), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.05
# -------------------------------------------------------------------
# Step counter = 13
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7800000000000002), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.05
# -------------------------------------------------------------------
# Step counter = 14
# Controller output: {'fcu_oveTSup_u': np.float64(285.2388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8000000000000003), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.06
# -------------------------------------------------------------------
# Step counter = 15
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8200000000000003), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.06
# -------------------------------------------------------------------
# Step counter = 16
# Controller output: {'fcu_oveTSup_u': np.float64(285.2388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8400000000000003), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.06
# -------------------------------------------------------------------
# Step counter = 17
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8600000000000003), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.07
# -------------------------------------------------------------------
# Step counter = 18
# Controller output: {'fcu_oveTSup_u': np.float64(285.2388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8800000000000003), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.07
# -------------------------------------------------------------------
# Step counter = 19
# Controller output: {'fcu_oveTSup_u': np.float64(286.0388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9000000000000004), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.07
# -------------------------------------------------------------------
# Step counter = 20
# Controller output: {'fcu_oveTSup_u': np.float64(286.8388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9200000000000004), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.08
# -------------------------------------------------------------------
# Step counter = 21
# Controller output: {'fcu_oveTSup_u': np.float64(287.6388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9400000000000004), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.08
# -------------------------------------------------------------------
# Step counter = 22
# Controller output: {'fcu_oveTSup_u': np.float64(288.4388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9600000000000004), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.08
# -------------------------------------------------------------------
# Step counter = 23
# Controller output: {'fcu_oveTSup_u': np.float64(289.23888888888894), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9800000000000004), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.09
# -------------------------------------------------------------------
# Step counter = 24
# Controller output: {'fcu_oveTSup_u': np.float64(290.03888888888895), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.09
# -------------------------------------------------------------------
# Step counter = 25
# Controller output: {'fcu_oveTSup_u': np.float64(290.83888888888896), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.09
# -------------------------------------------------------------------
# Step counter = 26
# Controller output: {'fcu_oveTSup_u': np.float64(291.63888888888897), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.10
# -------------------------------------------------------------------
# Step counter = 27
# Controller output: {'fcu_oveTSup_u': np.float64(292.438888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.10
# -------------------------------------------------------------------
# Step counter = 28
# Controller output: {'fcu_oveTSup_u': np.float64(293.238888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.10
# -------------------------------------------------------------------
# Step counter = 29
# Controller output: {'fcu_oveTSup_u': np.float64(294.038888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.11
# -------------------------------------------------------------------
# Step counter = 30
# Controller output: {'fcu_oveTSup_u': np.float64(294.838888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.11
# -------------------------------------------------------------------
# Step counter = 31
# Controller output: {'fcu_oveTSup_u': np.float64(295.638888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.11
# -------------------------------------------------------------------
# Step counter = 32
# Controller output: {'fcu_oveTSup_u': np.float64(296.43888888888904), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.12
# -------------------------------------------------------------------
# Step counter = 33
# Controller output: {'fcu_oveTSup_u': np.float64(297.23888888888905), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.12
# -------------------------------------------------------------------
# Step counter = 34
# Controller output: {'fcu_oveTSup_u': np.float64(298.03888888888906), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.12
# -------------------------------------------------------------------
# Step counter = 35
# Controller output: {'fcu_oveTSup_u': np.float64(298.8388888888891), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.13
# -------------------------------------------------------------------
# Step counter = 36
# Controller output: {'fcu_oveTSup_u': np.float64(299.6388888888891), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.13
# -------------------------------------------------------------------
# Step counter = 37
# Controller output: {'fcu_oveTSup_u': np.float64(300.4388888888891), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.14
# -------------------------------------------------------------------
# Step counter = 38
# Controller output: {'fcu_oveTSup_u': np.float64(301.2388888888891), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.14
# -------------------------------------------------------------------
# Step counter = 39
# Controller output: {'fcu_oveTSup_u': np.float64(302.0388888888891), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.14
# -------------------------------------------------------------------
# Step counter = 40
# Controller output: {'fcu_oveTSup_u': np.float64(302.83888888888913), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.15
# -------------------------------------------------------------------
# Step counter = 41
# Controller output: {'fcu_oveTSup_u': np.float64(303.63888888888914), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.15
# -------------------------------------------------------------------
# Step counter = 42
# Controller output: {'fcu_oveTSup_u': np.float64(304.43888888888915), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.15
# -------------------------------------------------------------------
# Step counter = 43
# Controller output: {'fcu_oveTSup_u': np.float64(305.23888888888916), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.16
# -------------------------------------------------------------------
# Step counter = 44
# Controller output: {'fcu_oveTSup_u': np.float64(306.0388888888892), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.16
# -------------------------------------------------------------------
# Step counter = 45
# Controller output: {'fcu_oveTSup_u': np.float64(306.8388888888892), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.16
# -------------------------------------------------------------------
# Step counter = 46
# Controller output: {'fcu_oveTSup_u': np.float64(307.6388888888892), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.17
# -------------------------------------------------------------------
# Step counter = 47
# Controller output: {'fcu_oveTSup_u': np.float64(308.4388888888892), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.17
# -------------------------------------------------------------------
# Step counter = 48
# Controller output: {'fcu_oveTSup_u': np.float64(309.2388888888892), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.17
# -------------------------------------------------------------------
# Step counter = 49
# Controller output: {'fcu_oveTSup_u': np.float64(310.03888888888923), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.18
# -------------------------------------------------------------------
# Step counter = 50
# Controller output: {'fcu_oveTSup_u': np.float64(310.83888888888924), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.18
# -------------------------------------------------------------------
# Step counter = 51
# Controller output: {'fcu_oveTSup_u': np.float64(311.63888888888926), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9977777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.18
# -------------------------------------------------------------------
# Step counter = 52
# Controller output: {'fcu_oveTSup_u': np.float64(312.43888888888927), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9777777777777777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.19
# -------------------------------------------------------------------
# Step counter = 53
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9577777777777777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.19
# -------------------------------------------------------------------
# Step counter = 54
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9377777777777777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.19
# -------------------------------------------------------------------
# Step counter = 55
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9177777777777777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.20
# -------------------------------------------------------------------
# Step counter = 56
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8977777777777777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.20
# -------------------------------------------------------------------
# Step counter = 57
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8777777777777777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.20
# -------------------------------------------------------------------
# Step counter = 58
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8577777777777776), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.21
# -------------------------------------------------------------------
# Step counter = 59
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8377777777777776), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.21
# -------------------------------------------------------------------
# Step counter = 60
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8177777777777776), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.22
# -------------------------------------------------------------------
# Step counter = 61
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7977777777777776), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.22
# -------------------------------------------------------------------
# Step counter = 62
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7777777777777776), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.22
# -------------------------------------------------------------------
# Step counter = 63
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7577777777777776), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.23
# -------------------------------------------------------------------
# Step counter = 64
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7377777777777775), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.23
# -------------------------------------------------------------------
# Step counter = 65
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7177777777777775), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.23
# -------------------------------------------------------------------
# Step counter = 66
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6977777777777775), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.24
# -------------------------------------------------------------------
# Step counter = 67
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6777777777777775), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.24
# -------------------------------------------------------------------
# Step counter = 68
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6577777777777775), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.24
# -------------------------------------------------------------------
# Step counter = 69
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6377777777777774), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.25
# -------------------------------------------------------------------
# Step counter = 70
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6177777777777774), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.25
# -------------------------------------------------------------------
# Step counter = 71
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5977777777777774), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.25
# -------------------------------------------------------------------
# Step counter = 72
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5777777777777774), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.26
# -------------------------------------------------------------------
# Step counter = 73
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5577777777777774), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.26
# -------------------------------------------------------------------
# Step counter = 74
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5377777777777774), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.26
# -------------------------------------------------------------------
# Step counter = 75
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5177777777777773), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.27
# -------------------------------------------------------------------
# Step counter = 76
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4977777777777773), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.27
# -------------------------------------------------------------------
# Step counter = 77
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4777777777777773), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.27
# -------------------------------------------------------------------
# Step counter = 78
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4577777777777773), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.28
# -------------------------------------------------------------------
# Step counter = 79
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.43777777777777727), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.28
# -------------------------------------------------------------------
# Step counter = 80
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.41777777777777725), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.28
# -------------------------------------------------------------------
# Step counter = 81
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.39777777777777723), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.29
# -------------------------------------------------------------------
# Step counter = 82
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3777777777777772), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.29
# -------------------------------------------------------------------
# Step counter = 83
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3577777777777772), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.30
# -------------------------------------------------------------------
# Step counter = 84
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3377777777777772), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.30
# -------------------------------------------------------------------
# Step counter = 85
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.31777777777777716), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.30
# -------------------------------------------------------------------
# Step counter = 86
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.29777777777777714), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.31
# -------------------------------------------------------------------
# Step counter = 87
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.2777777777777771), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.31
# -------------------------------------------------------------------
# Step counter = 88
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.2577777777777771), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.31
# -------------------------------------------------------------------
# Step counter = 89
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.23777777777777712), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.32
# -------------------------------------------------------------------
# Step counter = 90
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.21777777777777713), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.32
# -------------------------------------------------------------------
# Step counter = 91
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.19777777777777714), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.32
# -------------------------------------------------------------------
# Step counter = 92
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.17777777777777715), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.33
# -------------------------------------------------------------------
# Step counter = 93
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.15777777777777716), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.33
# -------------------------------------------------------------------
# Step counter = 94
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.13777777777777717), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.33
# -------------------------------------------------------------------
# Step counter = 95
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.11777777777777716), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.34
# -------------------------------------------------------------------
# Step counter = 96
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.09777777777777716), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.34
# -------------------------------------------------------------------
# Step counter = 97
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.07777777777777715), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.34
# -------------------------------------------------------------------
# Step counter = 98
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.05777777777777715), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.35
# -------------------------------------------------------------------
# Step counter = 99
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.03777777777777715), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.35
# -------------------------------------------------------------------
# Step counter = 100
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.017777777777777146), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.35
# -------------------------------------------------------------------
# Step counter = 101
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.36
# -------------------------------------------------------------------
# Step counter = 102
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.36
# -------------------------------------------------------------------
# Step counter = 103
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.36
# -------------------------------------------------------------------
# Step counter = 104
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.37
# -------------------------------------------------------------------
# Step counter = 105
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.37
# -------------------------------------------------------------------
# Step counter = 106
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.38
# -------------------------------------------------------------------
# Step counter = 107
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.38
# -------------------------------------------------------------------
# Step counter = 108
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.38
# -------------------------------------------------------------------
# Step counter = 109
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.39
# -------------------------------------------------------------------
# Step counter = 110
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.39
# -------------------------------------------------------------------
# Step counter = 111
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.39
# -------------------------------------------------------------------
# Step counter = 112
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.40
# -------------------------------------------------------------------
# Step counter = 113
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.40
# -------------------------------------------------------------------
# Step counter = 114
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.40
# -------------------------------------------------------------------
# Step counter = 115
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.41
# -------------------------------------------------------------------
# Step counter = 116
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.41
# -------------------------------------------------------------------
# Step counter = 117
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.41
# -------------------------------------------------------------------
# Step counter = 118
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.42
# -------------------------------------------------------------------
# Step counter = 119
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.42
# -------------------------------------------------------------------
# Step counter = 120
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.42
# -------------------------------------------------------------------
# Step counter = 121
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.43
# -------------------------------------------------------------------
# Step counter = 122
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.43
# -------------------------------------------------------------------
# Step counter = 123
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.43
# -------------------------------------------------------------------
# Step counter = 124
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.44
# -------------------------------------------------------------------
# Step counter = 125
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.44
# -------------------------------------------------------------------
# Step counter = 126
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.44
# -------------------------------------------------------------------
# Step counter = 127
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.45
# -------------------------------------------------------------------
# Step counter = 128
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.45
# -------------------------------------------------------------------
# Step counter = 129
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.45
# -------------------------------------------------------------------
# Step counter = 130
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.46
# -------------------------------------------------------------------
# Step counter = 131
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.46
# -------------------------------------------------------------------
# Step counter = 132
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.47
# -------------------------------------------------------------------
# Step counter = 133
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.47
# -------------------------------------------------------------------
# Step counter = 134
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.47
# -------------------------------------------------------------------
# Step counter = 135
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.48
# -------------------------------------------------------------------
# Step counter = 136
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.48
# -------------------------------------------------------------------
# Step counter = 137
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.48
# -------------------------------------------------------------------
# Step counter = 138
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.49
# -------------------------------------------------------------------
# Step counter = 139
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.49
# -------------------------------------------------------------------
# Step counter = 140
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.49
# -------------------------------------------------------------------
# Step counter = 141
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.50
# -------------------------------------------------------------------
# Step counter = 142
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.50
# -------------------------------------------------------------------
# Step counter = 143
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.50
# -------------------------------------------------------------------
# Step counter = 144
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.51
# -------------------------------------------------------------------
# Step counter = 145
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.51
# -------------------------------------------------------------------
# Step counter = 146
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.51
# -------------------------------------------------------------------
# Step counter = 147
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.52
# -------------------------------------------------------------------
# Step counter = 148
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.52
# -------------------------------------------------------------------
# Step counter = 149
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.52
# -------------------------------------------------------------------
# Step counter = 150
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.53
# -------------------------------------------------------------------
# Step counter = 151
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.53
# -------------------------------------------------------------------
# Step counter = 152
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.53
# -------------------------------------------------------------------
# Step counter = 153
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.54
# -------------------------------------------------------------------
# Step counter = 154
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.54
# -------------------------------------------------------------------
# Step counter = 155
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.55
# -------------------------------------------------------------------
# Step counter = 156
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.55
# -------------------------------------------------------------------
# Step counter = 157
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.55
# -------------------------------------------------------------------
# Step counter = 158
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.56
# -------------------------------------------------------------------
# Step counter = 159
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.56
# -------------------------------------------------------------------
# Step counter = 160
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.56
# -------------------------------------------------------------------
# Step counter = 161
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.57
# -------------------------------------------------------------------
# Step counter = 162
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.57
# -------------------------------------------------------------------
# Step counter = 163
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.57
# -------------------------------------------------------------------
# Step counter = 164
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.58
# -------------------------------------------------------------------
# Step counter = 165
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.58
# -------------------------------------------------------------------
# Step counter = 166
# ...
# Step counter = 233
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.82
# -------------------------------------------------------------------
# Step counter = 234
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.82
# -------------------------------------------------------------------
# Step counter = 235
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.82
# -------------------------------------------------------------------
# Step counter = 236
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.83
# -------------------------------------------------------------------
# Step counter = 237
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.83
# -------------------------------------------------------------------
# Step counter = 238
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.83
# -------------------------------------------------------------------
# Step counter = 239
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.84
# -------------------------------------------------------------------
# Step counter = 240
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.84
# -------------------------------------------------------------------
# Step counter = 241
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.84
# -------------------------------------------------------------------
# Step counter = 242
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.85
# -------------------------------------------------------------------
# Step counter = 243
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.85
# -------------------------------------------------------------------
# Step counter = 244
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.85
# -------------------------------------------------------------------
# Step counter = 245
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.86
# -------------------------------------------------------------------
# Step counter = 246
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.86
# -------------------------------------------------------------------
# Step counter = 247
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.86
# -------------------------------------------------------------------
# Step counter = 248
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.87
# -------------------------------------------------------------------
# Step counter = 249
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.87
# -------------------------------------------------------------------
# Step counter = 250
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.88
# -------------------------------------------------------------------
# Step counter = 251
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.88
# -------------------------------------------------------------------
# Step counter = 252
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.88
# -------------------------------------------------------------------
# Step counter = 253
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.89
# -------------------------------------------------------------------
# Step counter = 254
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.89
# -------------------------------------------------------------------
# Step counter = 255
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.89
# -------------------------------------------------------------------
# Step counter = 256
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.90
# -------------------------------------------------------------------
# Step counter = 257
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.90
# -------------------------------------------------------------------
# Step counter = 258
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.90
# -------------------------------------------------------------------
# Step counter = 259
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.91
# -------------------------------------------------------------------
# Step counter = 260
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.91
# -------------------------------------------------------------------
# Step counter = 261
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.91
# -------------------------------------------------------------------
# Step counter = 262
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.92
# -------------------------------------------------------------------
# Step counter = 263
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.92
# -------------------------------------------------------------------
# Step counter = 264
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.92
# -------------------------------------------------------------------
# Step counter = 265
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.93
# -------------------------------------------------------------------
# Step counter = 266
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.93
# -------------------------------------------------------------------
# Step counter = 267
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.93
# -------------------------------------------------------------------
# Step counter = 268
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.94
# -------------------------------------------------------------------
# Step counter = 269
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.94
# -------------------------------------------------------------------
# Step counter = 270
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.94
# -------------------------------------------------------------------
# Step counter = 271
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.95
# -------------------------------------------------------------------
# Step counter = 272
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.95
# -------------------------------------------------------------------
# Step counter = 273
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.95
# -------------------------------------------------------------------
# Step counter = 274
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.96
# -------------------------------------------------------------------
# Step counter = 275
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.96
# -------------------------------------------------------------------
# Step counter = 276
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.97
# -------------------------------------------------------------------
# Step counter = 277
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.97
# -------------------------------------------------------------------
# Step counter = 278
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.97
# -------------------------------------------------------------------
# Step counter = 279
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.98
# -------------------------------------------------------------------
# Step counter = 280
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.98
# -------------------------------------------------------------------
# Step counter = 281
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.98
# -------------------------------------------------------------------
# Step counter = 282
# Controller output: {'fcu_oveTSup_u': np.float64(313.0611111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.99
# -------------------------------------------------------------------
# Step counter = 283
# Controller output: {'fcu_oveTSup_u': np.float64(312.26111111111106), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.99
# -------------------------------------------------------------------
# Step counter = 284
# Controller output: {'fcu_oveTSup_u': np.float64(311.46111111111105), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.99
# -------------------------------------------------------------------
# Step counter = 285
# Controller output: {'fcu_oveTSup_u': np.float64(310.66111111111104), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.00
# -------------------------------------------------------------------
# Step counter = 286
# Controller output: {'fcu_oveTSup_u': np.float64(309.86111111111103), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.00
# -------------------------------------------------------------------
# Step counter = 287
# Controller output: {'fcu_oveTSup_u': np.float64(309.061111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.00
# -------------------------------------------------------------------
# Step counter = 288
# Controller output: {'fcu_oveTSup_u': np.float64(308.261111111111), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0022222222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.01

# %%
def get_and_plot_results(testid, start_time, final_time):
    points = ['zon_reaTRooAir_y', 'fcu_oveTSup_u', 'fcu_oveFan_u', 'zon_weaSta_reaWeaTDryBul_y']
    args = {
        'point_names': points,
        'start_time': start_time, 
        'final_time': final_time
    }
    
    response = requests.put('{0}/results/{1}'.format(url, testid), json=args).json()
    
    if 'payload' not in response:
        print("Error: Could not retrieve data. Check if testid is still active.")
        return None
        
    df_res = pd.DataFrame(data=response['payload'])
    
    df_res = df_res.set_index('time')
    x_time = df_res.index / 3600. / 24.
    x_time = x_time - (start_time / 3600. / 24.)
    df_res['time'] = x_time
    

    plt.close('all')
    fig, axs = plt.subplots(4, 1, sharex=True, figsize=(10, 10))
    
    axs[0].plot(x_time, df_res['zon_reaTRooAir_y'] - 273.15, color='darkorange', linewidth=0.8, label='$T_z$')
    axs[0].set_ylabel('Operative\nTemp ($^\circ$C)')
    axs[0].legend(loc='upper right')
    axs[0].grid(True)

    axs[1].plot(x_time, df_res['zon_weaSta_reaWeaTDryBul_y'] - 273.15, color='green', linewidth=0.8, label='$T_{amb}$')
    axs[1].set_ylabel('Ambient\nTemp ($^\circ$C)')
    axs[1].legend(loc='upper right')
    axs[1].grid(True)

    axs[2].plot(x_time, df_res['fcu_oveTSup_u'] - 273.15, color='red', linewidth=0.8, label='$fcu_oveTSup_u$')
    axs[2].legend(loc='upper right')
    axs[2].grid(True)

    axs[3].plot(x_time, df_res['fcu_oveFan_u'], color='royalblue', linewidth=0.8, label='$fcu_oveFan_u$')
    axs[3].set_xlabel('Time (days)')
    axs[3].legend(loc='upper right')
    axs[3].grid(True)

    plt.tight_layout()
    plt.show()
    
    return df_res

start_in_seconds = start_time_days * 24 * 3600
final_in_seconds = start_in_seconds + (14 * 24 * 3600)

get_and_plot_results(testid=testid, start_time=start_in_seconds, final_time=final_in_seconds)
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\namng\AppData\Local\Temp\ipykernel_37900\137404845.py:33: SyntaxWarning: invalid escape sequence '\c'
#   axs[0].set_ylabel('Operative\nTemp ($^\circ$C)')
# C:\Users\namng\AppData\Local\Temp\ipykernel_37900\137404845.py:39: SyntaxWarning: invalid escape sequence '\c'
#   axs[1].set_ylabel('Ambient\nTemp ($^\circ$C)')
#          zon_reaTRooAir_y  fcu_oveTSup_u  fcu_oveFan_u  \
# time
# 3801600        295.310128     294.150000      0.000000
# 3801630        295.222125     293.150000      0.500000
# 3801660        295.117210     293.150000      0.500000
# 3801690        295.023884     293.150000      0.500000
# 3801720        294.940950     293.150000      0.500000
# ...                   ...            ...           ...
# 3888480        289.543453     308.261111      0.002222
# 3888510        289.540107     308.261111      0.002222
# 3888540        289.536635     308.261111      0.002222
# 3888570        289.533046     308.261111      0.002222
# 3888600        289.529348     308.261111      0.002222
#
#          zon_weaSta_reaWeaTDryBul_y      time
# time
# 3801600                  279.050000  0.000000
# 3801630                  279.025812  0.000347
# 3801660                  279.001625  0.000694
# 3801690                  278.977439  0.001042
# 3801720                  278.953254  0.001389
# ...                             ...       ...
# 3888480                  268.916667  1.005556
# 3888510                  268.908333  1.005903
# 3888540                  268.900000  1.006250
# 3888570                  268.891667  1.006597
# 3888600                  268.883333  1.006944
#
# [2901 rows x 5 columns]

# %%
ls_rmse = [t.cpu()*30 for t in ls_rmse]

# %%
plt.plot(ls_rmse[:1000])
plt.xlabel('Iteration (number of new data points)')
plt.grid()
plt.ylabel('RMSE (F)')
plt.title('Active learning for GP model RMSE')
plt.show()

# %%
df = pd.DataFrame(np.array(ls_rmse), columns=["RMSE_AL_GP"])
file_name = f"RMSE_MV_GP_ini{Ne_tr}_{const.ramp}.csv"
save_dir = os.path.join(save_dir, file_name)
df.to_csv(save_dir, index=False)

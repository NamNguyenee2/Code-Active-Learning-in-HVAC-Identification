# %%
import requests
import numpy as np
import casadi as ca
import matplotlib.pyplot as plt
from IPython.display import clear_output
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import gpytorch
from common import get_data, to_tensor
import constant as const
from call_GP import train_GP, ExactGPModel, evaluate_gp, call_model, cal_pos

url = "http://127.0.0.1:80"
testcase = 'bestest_air'
testid = \
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using:", device)
print("done")
# Out:
# Using: cuda
# Using: cuda
# done

# %%
step = const.step

data = pd.read_csv(f'processed_uniform_low_step_5m_data.csv')
data_test = data

data.head()
# Out:
#    fcu_oveTSup_u  fcu_oveFan_u  zon_reaTRooAir_y  zon_weaSta_reaWeaTDryBul_y  \
# 0     293.150000      0.500000        294.435431                  273.696865
# 1     299.449048      0.300000        295.614446                  273.540664
# 2     291.449048      0.157235        294.753102                  273.382031
# 3     295.113814      0.104030        294.769918                  273.221605
# 4     287.113814      0.304030        293.240590                  273.060021
#
#        time
# 0  28857900
# 1  28858200
# 2  28858500
# 3  28858800
# 4  28859100

# %%
T_zone = (data['zon_reaTRooAir_y'].values - 273.15) / 30.0
T_sup  = (data['fcu_oveTSup_u'].values - 273.15) / 40.0
fan  = data['fcu_oveFan_u'].values
T_out = (data['zon_weaSta_reaWeaTDryBul_y'].values - 273.15) / 10.0


pos_T_zone = T_zone[1:]
cur_T_zone = T_zone[:-1]
cur_T_sup = T_sup[:-1]
cur_fan = fan[:-1]
cur_T_out = T_out[:-1]


def data_split(Ns, Ne, x1, x2, x3, x4, x5):
    return (to_tensor(x1[Ns:Ne]).view(-1,1), to_tensor(x2[Ns:Ne]).view(-1,1),
            to_tensor(x3[Ns:Ne]).view(-1,1), to_tensor(x4[Ns:Ne]).view(-1,1), to_tensor(x5[Ns:Ne]).view(-1,1))


Ns_tr, Ne_tr = const.Ns_tr, const.Ne_tr  
Ns_t, Ne_t = const.Ns_t, const.Ne_t 
cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr, pos_T_zone_tr = data_split(Ns_tr, Ne_tr, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)
cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t, pos_T_zone_t = data_split(Ns_t, Ne_t, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)

X_tr = torch.cat((cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr), dim=1)
y_tr = pos_T_zone_tr.squeeze(-1)  
X_t = torch.cat((cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t), dim=1)
y_t = pos_T_zone_t.squeeze(-1)

ramp = const.ramp

# %%
testid = \
requests.post('{0}/testcases/{1}/select'.format(url,testcase)).json()['testid']
name = requests.get('{0}/name/{1}'.format(url, testid)).json()['payload']
print(name)

version = requests.get('{0}/version'.format(url)).json()['payload']
print(version)
inputs = requests.get('{0}/inputs/{1}'.format(url, testid)).json()['payload']
print('TEST CASE INPUTS ---------------------------------------------')
print(inputs.keys())

print('TEST CASE MEASUREMENTS ---------------------------------------')
measurements = requests.get('{0}/measurements/{1}'.format(url, testid)).json()['payload']
print(measurements.keys())
# Out:
# {'name': 'bestest_air'}
# {'version': '0.8.0'}
# TEST CASE INPUTS ---------------------------------------------
# dict_keys(['con_oveTSetCoo_activate', 'con_oveTSetCoo_u', 'con_oveTSetHea_activate', 'con_oveTSetHea_u', 'fcu_oveFan_activate', 'fcu_oveFan_u', 'fcu_oveTSup_activate', 'fcu_oveTSup_u'])
# TEST CASE MEASUREMENTS ---------------------------------------
# dict_keys(['fcu_reaFloSup_y', 'fcu_reaPCoo_y', 'fcu_reaPFan_y', 'fcu_reaPHea_y', 'zon_reaCO2RooAir_y', 'zon_reaPLig_y', 'zon_reaPPlu_y', 'zon_reaTRooAir_y', 'zon_weaSta_reaWeaCeiHei_y', 'zon_weaSta_reaWeaCloTim_y', 'zon_weaSta_reaWeaHDifHor_y', 'zon_weaSta_reaWeaHDirNor_y', 'zon_weaSta_reaWeaHGloHor_y', 'zon_weaSta_reaWeaHHorIR_y', 'zon_weaSta_reaWeaLat_y', 'zon_weaSta_reaWeaLon_y', 'zon_weaSta_reaWeaNOpa_y', 'zon_weaSta_reaWeaNTot_y', 'zon_weaSta_reaWeaPAtm_y', 'zon_weaSta_reaWeaRelHum_y', 'zon_weaSta_reaWeaSolAlt_y', 'zon_weaSta_reaWeaSolDec_y', 'zon_weaSta_reaWeaSolHouAng_y', 'zon_weaSta_reaWeaSolTim_y', 'zon_weaSta_reaWeaSolZen_y', 'zon_weaSta_reaWeaTBlaSky_y', 'zon_weaSta_reaWeaTDewPoi_y', 'zon_weaSta_reaWeaTDryBul_y', 'zon_weaSta_reaWeaTWetBul_y', 'zon_weaSta_reaWeaWinDir_y', 'zon_weaSta_reaWeaWinSpe_y'])

# %% [markdown]
# Inputs:
# - con_oveTSetCoo_activate, con_oveTSetCoo_u
# - con_oveTSetHea_activate, con_oveTSetHea_u
#
# Output:
# - zon_reaTRooAir_y

# %%
def mpc_implement(horizon=1, u0_1=0.5, u0_2=0.5):
    n_grid = 10
 



    u_min_general = np.array([0.3, 0.])
    u_max_general = np.array([1.0, 1.0])

    u_min = np.clip(np.array([u0_1 - ramp, u0_2 - ramp]), u_min_general, u_max_general)
    u_max = np.clip(np.array([u0_1 + ramp, u0_2 + ramp]), u_min_general, u_max_general)

    u0_vals = np.linspace(u_min[0], u_max[0], n_grid)
    u1_vals = np.linspace(u_min[1], u_max[1], n_grid)
    
    u0 = np.random.choice(u0_vals)
    u1 = np.random.choice(u1_vals)

    u = {
        'fcu_oveTSup_u': u0 * 40 + 273.15,
        'fcu_oveTSup_activate': 1,
        'fcu_oveFan_u': u1,
        'fcu_oveFan_activate': 1
        }
    return u

# %%
y = requests.put('{0}/scenario/{1}'.format(url, testid), 
                 json={'time_period':'typical_heat_day',
                       'electricity_price':'dynamic'}).json()['payload']['time_period']
requests.put('{0}/step/{1}'.format(url, testid), json={'step':step*60})
start_time_days = y['time']/3600/24
train_GP(X_tr=X_tr, y_tr=y_tr, save_path=f'model_PL_GP_{step}m.pth', ori=0)

# %%
last_change_day = start_time_days
counter = 0
u0_1 = 0.5
u0_2 = 0.5
u = {
        'fcu_oveTSup_u': u0_1 * 40 + 273.15,
        'fcu_oveTSup_activate': 1,
        'fcu_oveFan_u': u0_2,
        'fcu_oveFan_activate': 1
        }

x_ref = 25
simulation_time_days = y['time']/3600/24
print('Simulation time [elapsed days] = {:.2f}'.format((simulation_time_days - start_time_days)))
y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  

ls_rmse = [evaluate_gp(X_tr, y_tr, X_t, y_t, save_path=f'model_PL_GP_{step}m.pth')]
X_tr_new = X_tr
y_tr_new = y_tr
num_count = const.num_count

print('Initial RMSE: {:.4f}'.format(ls_rmse[-1]))
# Out:
# Simulation time [elapsed days] = 0.00
# Initial RMSE: 0.2775

# %%
while y:
    x0 = y['zon_reaTRooAir_y']-273.15
    u = mpc_implement(horizon=1, u0_1=u0_1, u0_2=u0_2)

    print('-------------------------------------------------------------------')
    print('Step counter =', counter)
    print("Controller output:", u)

    y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  
    counter += 1


    cur = to_tensor(x0).view(-1,1)/30.0

    T_sup_add=  to_tensor((u['fcu_oveTSup_u']-273.15)/40.0).view(-1,1)
    fan_add = to_tensor(u['fcu_oveFan_u']).view(-1,1)
    pos_add = to_tensor(y['zon_reaTRooAir_y']-273.15).view(-1,1)/30.0
    T_out_add = to_tensor((y['zon_weaSta_reaWeaTDryBul_y']-273.15)/10.0).view(-1,1)

    X_tr_n = torch.cat((cur, T_sup_add, fan_add, T_out_add), dim=1)

    y_tr_n = pos_add.squeeze(-1)   

    X_tr_new = torch.cat((X_tr_new, X_tr_n), dim=0)
    y_tr_new = torch.cat((y_tr_new, y_tr_n), dim=0)
    
    if const.count_data == const.number_of_data:
        print("=======retrain GP model=======")
        train_GP(X_tr=X_tr_new, y_tr=y_tr_new, save_path=f'model_PL_GP_{step}m.pth', ori=1)
        const.count_data = 0
    const.count_data += 1
    simulation_time_days = y['time']/3600/24
    print('Simulation time [elapsed days] = {:.2f}'.format((simulation_time_days - start_time_days)))

    u0_1 = (u['fcu_oveTSup_u']-273.15)/40.0
    u0_2 = u['fcu_oveFan_u']

    rmse = evaluate_gp(X_tr_new, y_tr_new, X_t, y_t, save_path=f'model_PL_GP_{step}m.pth')

    ls_rmse.append(rmse)
    if counter > num_count:
        break
# Out:
# -------------------------------------------------------------------
# Step counter = 0
# Controller output: {'fcu_oveTSup_u': np.float64(301.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6555555555555554), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.01
# -------------------------------------------------------------------
# Step counter = 1
# Controller output: {'fcu_oveTSup_u': np.float64(300.26111111111106), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5444444444444443), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.01
# -------------------------------------------------------------------
# Step counter = 2
# Controller output: {'fcu_oveTSup_u': np.float64(297.5944444444444), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7444444444444442), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.01
# -------------------------------------------------------------------
# Step counter = 3
# Controller output: {'fcu_oveTSup_u': np.float64(289.5944444444444), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.722222222222222), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.02
# -------------------------------------------------------------------
# Step counter = 4
# Controller output: {'fcu_oveTSup_u': np.float64(293.4462962962962), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6555555555555553), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.02
# -------------------------------------------------------------------
# Step counter = 5
# Controller output: {'fcu_oveTSup_u': np.float64(294.3351851851851), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4999999999999998), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.02
# -------------------------------------------------------------------
# Step counter = 6
# Controller output: {'fcu_oveTSup_u': np.float64(289.8907407407406), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6111111111111108), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.03
# -------------------------------------------------------------------
# Step counter = 7
# Controller output: {'fcu_oveTSup_u': np.float64(289.39691358024686), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8111111111111109), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.03
# -------------------------------------------------------------------
# Step counter = 8
# Controller output: {'fcu_oveTSup_u': np.float64(289.2323045267489), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.03
# -------------------------------------------------------------------
# Step counter = 9
# Controller output: {'fcu_oveTSup_u': np.float64(290.5199131229995), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9777777777777777), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.04
# -------------------------------------------------------------------
# Step counter = 10
# Controller output: {'fcu_oveTSup_u': np.float64(289.6066377076665), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9506172839506173), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.04
# -------------------------------------------------------------------
# Step counter = 11
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8614540466392319), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.05
# -------------------------------------------------------------------
# Step counter = 12
# Controller output: {'fcu_oveTSup_u': np.float64(286.0388888888889), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6990702636793171), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.05
# -------------------------------------------------------------------
# Step counter = 13
# Controller output: {'fcu_oveTSup_u': np.float64(287.12530864197527), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7212924859015393), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.05
# -------------------------------------------------------------------
# Step counter = 14
# Controller output: {'fcu_oveTSup_u': np.float64(292.90857338820297), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5657369303459837), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.06
# -------------------------------------------------------------------
# Step counter = 15
# Controller output: {'fcu_oveTSup_u': np.float64(295.6557155921353), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.41018137479042815), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.06
# -------------------------------------------------------------------
# Step counter = 16
# Controller output: {'fcu_oveTSup_u': np.float64(301.87793781435755), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5657369303459836), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.06
# -------------------------------------------------------------------
# Step counter = 17
# Controller output: {'fcu_oveTSup_u': np.float64(306.322382258802), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5879591525682057), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.07
# -------------------------------------------------------------------
# Step counter = 18
# Controller output: {'fcu_oveTSup_u': np.float64(301.61740842351264), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4768480414570946), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.07
# -------------------------------------------------------------------
# Step counter = 19
# Controller output: {'fcu_oveTSup_u': np.float64(309.61740842351264), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.45462581923487233), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.07
# -------------------------------------------------------------------
# Step counter = 20
# Controller output: {'fcu_oveTSup_u': np.float64(308.0244037437834), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5212924859015391), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.08
# -------------------------------------------------------------------
# Step counter = 21
# Controller output: {'fcu_oveTSup_u': np.float64(307.3164016639037), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3212924859015391), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.08
# -------------------------------------------------------------------
# Step counter = 22
# Controller output: {'fcu_oveTSup_u': np.float64(303.9276011092691), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4324035970126502), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.08
# -------------------------------------------------------------------
# Step counter = 23
# Controller output: {'fcu_oveTSup_u': np.float64(308.3720455537136), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6324035970126503), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.09
# -------------------------------------------------------------------
# Step counter = 24
# Controller output: {'fcu_oveTSup_u': np.float64(311.73022728374593), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6990702636793169), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.09
# -------------------------------------------------------------------
# Step counter = 25
# Controller output: {'fcu_oveTSup_u': np.float64(304.77686869666303), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.721292485901539), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.09
# -------------------------------------------------------------------
# Step counter = 26
# Controller output: {'fcu_oveTSup_u': np.float64(300.3324242522186), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8324035970126501), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.10
# -------------------------------------------------------------------
# Step counter = 27
# Controller output: {'fcu_oveTSup_u': np.float64(302.99909091888526), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.63240359701265), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.10
# -------------------------------------------------------------------
# Step counter = 28
# Controller output: {'fcu_oveTSup_u': np.float64(309.2213131411075), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7879591525682055), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.10
# -------------------------------------------------------------------
# Step counter = 29
# Controller output: {'fcu_oveTSup_u': np.float64(311.82459034901194), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7212924859015388), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.11
# -------------------------------------------------------------------
# Step counter = 30
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9212924859015388), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.11
# -------------------------------------------------------------------
# Step counter = 31
# Controller output: {'fcu_oveTSup_u': np.float64(310.4833333333333), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7832274890345302), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.11
# -------------------------------------------------------------------
# Step counter = 32
# Controller output: {'fcu_oveTSup_u': np.float64(309.59444444444443), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9832274890345303), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.12
# -------------------------------------------------------------------
# Step counter = 33
# Controller output: {'fcu_oveTSup_u': np.float64(305.4462962962963), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8554849926896869), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.12
# -------------------------------------------------------------------
# Step counter = 34
# Controller output: {'fcu_oveTSup_u': np.float64(306.1705761316872), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8086027737164927), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.12
# -------------------------------------------------------------------
# Step counter = 35
# Controller output: {'fcu_oveTSup_u': np.float64(298.1705761316872), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9130228386036651), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.13
# -------------------------------------------------------------------
# Step counter = 36
# Controller output: {'fcu_oveTSup_u': np.float64(297.2816872427983), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9681136487337405), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.13
# -------------------------------------------------------------------
# Step counter = 37
# Controller output: {'fcu_oveTSup_u': np.float64(303.5039094650205), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8196439490151315), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.14
# -------------------------------------------------------------------
# Step counter = 38
# Controller output: {'fcu_oveTSup_u': np.float64(300.8372427983538), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8732146496717106), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.14
# -------------------------------------------------------------------
# Step counter = 39
# Controller output: {'fcu_oveTSup_u': np.float64(301.72613168724274), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.14
# -------------------------------------------------------------------
# Step counter = 40
# Controller output: {'fcu_oveTSup_u': np.float64(300.8372427983538), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9333333333333333), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.15
# -------------------------------------------------------------------
# Step counter = 41
# Controller output: {'fcu_oveTSup_u': np.float64(294.6150205761316), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9407407407407408), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.15
# -------------------------------------------------------------------
# Step counter = 42
# Controller output: {'fcu_oveTSup_u': np.float64(297.2816872427983), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8271604938271605), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.15
# -------------------------------------------------------------------
# Step counter = 43
# Controller output: {'fcu_oveTSup_u': np.float64(305.2816872427983), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9171467764060357), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.16
# -------------------------------------------------------------------
# Step counter = 44
# Controller output: {'fcu_oveTSup_u': np.float64(297.2816872427983), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9057155921353452), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.16
# -------------------------------------------------------------------
# Step counter = 45
# Controller output: {'fcu_oveTSup_u': np.float64(301.72613168724274), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8038103947568969), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.16
# -------------------------------------------------------------------
# Step counter = 46
# Controller output: {'fcu_oveTSup_u': np.float64(307.94835390946497), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9559789327507664), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.17
# -------------------------------------------------------------------
# Step counter = 47
# Controller output: {'fcu_oveTSup_u': np.float64(301.41520347508), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8644327404170925), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.17
# -------------------------------------------------------------------
# Step counter = 48
# Controller output: {'fcu_oveTSup_u': np.float64(304.08187014174666), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9627147489352326), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.17
# -------------------------------------------------------------------
# Step counter = 49
# Controller output: {'fcu_oveTSup_u': np.float64(310.3040923639689), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9209049163117442), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.18
# -------------------------------------------------------------------
# Step counter = 50
# Controller output: {'fcu_oveTSup_u': np.float64(310.7397983031042), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8759577405829975), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.18
# -------------------------------------------------------------------
# Step counter = 51
# Controller output: {'fcu_oveTSup_u': np.float64(305.0531764579699), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8919859135276658), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.18
# -------------------------------------------------------------------
# Step counter = 52
# Controller output: {'fcu_oveTSup_u': np.float64(297.0531764579699), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6919859135276658), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.19
# -------------------------------------------------------------------
# Step counter = 53
# Controller output: {'fcu_oveTSup_u': np.float64(305.0531764579699), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6253192468609992), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.19
# -------------------------------------------------------------------
# Step counter = 54
# Controller output: {'fcu_oveTSup_u': np.float64(304.164287569081), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8253192468609991), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.19
# -------------------------------------------------------------------
# Step counter = 55
# Controller output: {'fcu_oveTSup_u': np.float64(296.164287569081), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8751064156203331), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.20
# -------------------------------------------------------------------
# Step counter = 56
# Controller output: {'fcu_oveTSup_u': np.float64(289.9420653468588), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8195035642335183), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.20
# -------------------------------------------------------------------
# Step counter = 57
# Controller output: {'fcu_oveTSup_u': np.float64(287.99268118819083), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9577226182481686), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.20
# -------------------------------------------------------------------
# Step counter = 58
# Controller output: {'fcu_oveTSup_u': np.float64(294.7879388339474), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9192408727493896), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.21
# -------------------------------------------------------------------
# Step counter = 59
# Controller output: {'fcu_oveTSup_u': np.float64(290.34349438950295), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8440227070829942), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.21
# -------------------------------------------------------------------
# Step counter = 60
# Controller output: {'fcu_oveTSup_u': np.float64(288.0818876421117), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.22
# -------------------------------------------------------------------
# Step counter = 61
# Controller output: {'fcu_oveTSup_u': np.float64(286.36465418245683), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8222222222222223), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.22
# -------------------------------------------------------------------
# Step counter = 62
# Controller output: {'fcu_oveTSup_u': np.float64(294.36465418245683), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8740740740740741), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.22
# -------------------------------------------------------------------
# Step counter = 63
# Controller output: {'fcu_oveTSup_u': np.float64(289.9202097380124), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.891358024691358), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.23
# -------------------------------------------------------------------
# Step counter = 64
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7256515775034293), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.23
# -------------------------------------------------------------------
# Step counter = 65
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5700960219478738), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.23
# -------------------------------------------------------------------
# Step counter = 66
# Controller output: {'fcu_oveTSup_u': np.float64(287.81666666666666), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6367626886145406), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.24
# -------------------------------------------------------------------
# Step counter = 67
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6589849108367627), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.24
# -------------------------------------------------------------------
# Step counter = 68
# Controller output: {'fcu_oveTSup_u': np.float64(289.59444444444443), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7256515775034293), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.24
# -------------------------------------------------------------------
# Step counter = 69
# Controller output: {'fcu_oveTSup_u': np.float64(294.829012345679), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5256515775034294), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.25
# -------------------------------------------------------------------
# Step counter = 70
# Controller output: {'fcu_oveTSup_u': np.float64(288.6067901234568), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7256515775034293), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.25
# -------------------------------------------------------------------
# Step counter = 71
# Controller output: {'fcu_oveTSup_u': np.float64(294.0608367626886), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6145404663923183), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.25
# -------------------------------------------------------------------
# Step counter = 72
# Controller output: {'fcu_oveTSup_u': np.float64(296.7275034293553), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6367626886145406), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.26
# -------------------------------------------------------------------
# Step counter = 73
# Controller output: {'fcu_oveTSup_u': np.float64(302.9497256515775), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5256515775034294), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.26
# -------------------------------------------------------------------
# Step counter = 74
# Controller output: {'fcu_oveTSup_u': np.float64(300.28305898491084), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6367626886145404), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.26
# -------------------------------------------------------------------
# Step counter = 75
# Controller output: {'fcu_oveTSup_u': np.float64(306.50528120713307), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7034293552812072), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.27
# -------------------------------------------------------------------
# Step counter = 76
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8589849108367626), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.27
# -------------------------------------------------------------------
# Step counter = 77
# Controller output: {'fcu_oveTSup_u': np.float64(305.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.27
# -------------------------------------------------------------------
# Step counter = 78
# Controller output: {'fcu_oveTSup_u': np.float64(311.3722222222222), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.28
# -------------------------------------------------------------------
# Step counter = 79
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.28
# -------------------------------------------------------------------
# Step counter = 80
# Controller output: {'fcu_oveTSup_u': np.float64(307.81666666666666), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8666666666666667), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.28
# -------------------------------------------------------------------
# Step counter = 81
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.29
# -------------------------------------------------------------------
# Step counter = 82
# Controller output: {'fcu_oveTSup_u': np.float64(306.92777777777775), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8444444444444444), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.29
# -------------------------------------------------------------------
# Step counter = 83
# Controller output: {'fcu_oveTSup_u': np.float64(306.82901234567896), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(1.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.30
# -------------------------------------------------------------------
# Step counter = 84
# Controller output: {'fcu_oveTSup_u': np.float64(298.82901234567896), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9333333333333333), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.30
# -------------------------------------------------------------------
# Step counter = 85
# Controller output: {'fcu_oveTSup_u': np.float64(290.82901234567896), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8518518518518519), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.30
# -------------------------------------------------------------------
# Step counter = 86
# Controller output: {'fcu_oveTSup_u': np.float64(292.74945130315496), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6518518518518519), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.31
# -------------------------------------------------------------------
# Step counter = 87
# Controller output: {'fcu_oveTSup_u': np.float64(299.01617893613775), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5407407407407407), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.31
# -------------------------------------------------------------------
# Step counter = 88
# Controller output: {'fcu_oveTSup_u': np.float64(299.90506782502666), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6518518518518518), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.31
# -------------------------------------------------------------------
# Step counter = 89
# Controller output: {'fcu_oveTSup_u': np.float64(295.4606233805822), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7185185185185186), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.32
# -------------------------------------------------------------------
# Step counter = 90
# Controller output: {'fcu_oveTSup_u': np.float64(294.5717344916933), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5185185185185186), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.32
# -------------------------------------------------------------------
# Step counter = 91
# Controller output: {'fcu_oveTSup_u': np.float64(291.9050678250266), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4518518518518519), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.32
# -------------------------------------------------------------------
# Step counter = 92
# Controller output: {'fcu_oveTSup_u': np.float64(296.6261638639096), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5185185185185186), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.33
# -------------------------------------------------------------------
# Step counter = 93
# Controller output: {'fcu_oveTSup_u': np.float64(290.40394164168737), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.674074074074074), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.33
# -------------------------------------------------------------------
# Step counter = 94
# Controller output: {'fcu_oveTSup_u': np.float64(296.93128145927767), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6962962962962962), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.33
# -------------------------------------------------------------------
# Step counter = 95
# Controller output: {'fcu_oveTSup_u': np.float64(301.3757259037221), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.585185185185185), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.34
# -------------------------------------------------------------------
# Step counter = 96
# Controller output: {'fcu_oveTSup_u': np.float64(309.3757259037221), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4296296296296295), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.34
# -------------------------------------------------------------------
# Step counter = 97
# Controller output: {'fcu_oveTSup_u': np.float64(301.3757259037221), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.585185185185185), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.34
# -------------------------------------------------------------------
# Step counter = 98
# Controller output: {'fcu_oveTSup_u': np.float64(305.8201703481666), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.785185185185185), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.35
# -------------------------------------------------------------------
# Step counter = 99
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.896296296296296), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.35
# -------------------------------------------------------------------
# Step counter = 100
# Controller output: {'fcu_oveTSup_u': np.float64(310.4833333333333), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9325102880658436), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.35
# -------------------------------------------------------------------
# Step counter = 101
# Controller output: {'fcu_oveTSup_u': np.float64(302.4833333333333), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9702789208962048), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.36
# -------------------------------------------------------------------
# Step counter = 102
# Controller output: {'fcu_oveTSup_u': np.float64(310.4833333333333), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.795803485241071), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.36
# -------------------------------------------------------------------
# Step counter = 103
# Controller output: {'fcu_oveTSup_u': np.float64(309.59444444444443), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6846923741299599), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.36
# -------------------------------------------------------------------
# Step counter = 104
# Controller output: {'fcu_oveTSup_u': np.float64(310.5820987654321), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8402479296855154), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.37
# -------------------------------------------------------------------
# Step counter = 105
# Controller output: {'fcu_oveTSup_u': np.float64(304.93052126200274), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6402479296855155), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.37
# -------------------------------------------------------------------
# Step counter = 106
# Controller output: {'fcu_oveTSup_u': np.float64(304.0416323731138), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4846923741299599), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.38
# -------------------------------------------------------------------
# Step counter = 107
# Controller output: {'fcu_oveTSup_u': np.float64(312.0416323731138), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.32913681857440436), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.38
# -------------------------------------------------------------------
# Step counter = 108
# Controller output: {'fcu_oveTSup_u': np.float64(310.1138774577046), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.26247015190773765), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.38
# -------------------------------------------------------------------
# Step counter = 109
# Controller output: {'fcu_oveTSup_u': np.float64(309.47129248590153), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.10691459635218209), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.39
# -------------------------------------------------------------------
# Step counter = 110
# Controller output: {'fcu_oveTSup_u': np.float64(301.47129248590153), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.272812974535273), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.39
# -------------------------------------------------------------------
# Step counter = 111
# Controller output: {'fcu_oveTSup_u': np.float64(293.47129248590153), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.07281297453527297), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.39
# -------------------------------------------------------------------
# Step counter = 112
# Controller output: {'fcu_oveTSup_u': np.float64(299.69351470812376), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.03031255272614144), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.40
# -------------------------------------------------------------------
# Step counter = 113
# Controller output: {'fcu_oveTSup_u': np.float64(297.0268480414571), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.05118056727247588), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.40
# -------------------------------------------------------------------
# Step counter = 114
# Controller output: {'fcu_oveTSup_u': np.float64(292.5824035970126), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.08372685575749197), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.40
# -------------------------------------------------------------------
# Step counter = 115
# Controller output: {'fcu_oveTSup_u': np.float64(292.0088460431167), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.18915123717166135), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.41
# -------------------------------------------------------------------
# Step counter = 116
# Controller output: {'fcu_oveTSup_u': np.float64(291.75393157471854), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.08647805270481362), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.41
# -------------------------------------------------------------------
# Step counter = 117
# Controller output: {'fcu_oveTSup_u': np.float64(291.6406362554304), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.03183089474497929), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.41
# -------------------------------------------------------------------
# Step counter = 118
# Controller output: {'fcu_oveTSup_u': np.float64(298.03056556038257), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.1030359532199908), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.42
# -------------------------------------------------------------------
# Step counter = 119
# Controller output: {'fcu_oveTSup_u': np.float64(293.5861211159381), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.30303595321999083), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.42
# -------------------------------------------------------------------
# Step counter = 120
# Controller output: {'fcu_oveTSup_u': np.float64(298.03056556038257), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.19192484210887972), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.42
# -------------------------------------------------------------------
# Step counter = 121
# Controller output: {'fcu_oveTSup_u': np.float64(297.14167667149366), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.08709440935752882), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.43
# -------------------------------------------------------------------
# Step counter = 122
# Controller output: {'fcu_oveTSup_u': np.float64(289.14167667149366), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0956981364525096), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.43
# -------------------------------------------------------------------
# Step counter = 123
# Controller output: {'fcu_oveTSup_u': np.float64(286.48240851905484), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.16427674247361648), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.43
# -------------------------------------------------------------------
# Step counter = 124
# Controller output: {'fcu_oveTSup_u': np.float64(291.3716056793699), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.20237596804089805), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.44
# -------------------------------------------------------------------
# Step counter = 125
# Controller output: {'fcu_oveTSup_u': np.float64(294.63107045291326), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.22459819026312028), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.44
# -------------------------------------------------------------------
# Step counter = 126
# Controller output: {'fcu_oveTSup_u': np.float64(293.74218156402435), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3357093013742314), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.44
# -------------------------------------------------------------------
# Step counter = 127
# Controller output: {'fcu_oveTSup_u': np.float64(291.07551489735766), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3579315235964536), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.45
# -------------------------------------------------------------------
# Step counter = 128
# Controller output: {'fcu_oveTSup_u': np.float64(292.8863971651987), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3801537458186758), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.45
# -------------------------------------------------------------------
# Step counter = 129
# Controller output: {'fcu_oveTSup_u': np.float64(286.8984885739109), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.18015374581867577), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.45
# -------------------------------------------------------------------
# Step counter = 130
# Controller output: {'fcu_oveTSup_u': np.float64(290.5658269855061), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.12671791527289195), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.46
# -------------------------------------------------------------------
# Step counter = 131
# Controller output: {'fcu_oveTSup_u': np.float64(291.11258977133605), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.46
# -------------------------------------------------------------------
# Step counter = 132
# Controller output: {'fcu_oveTSup_u': np.float64(288.25279772696354), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.13333333333333333), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.47
# -------------------------------------------------------------------
# Step counter = 133
# Controller output: {'fcu_oveTSup_u': np.float64(287.6172883837697), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.1851851851851852), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.47
# -------------------------------------------------------------------
# Step counter = 134
# Controller output: {'fcu_oveTSup_u': np.float64(295.6172883837697), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.08559670781893004), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.47
# -------------------------------------------------------------------
# Step counter = 135
# Controller output: {'fcu_oveTSup_u': np.float64(291.1728439393252), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.22213077274805668), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.48
# -------------------------------------------------------------------
# Step counter = 136
# Controller output: {'fcu_oveTSup_u': np.float64(296.05665639725294), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.06657521719250112), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.48
# -------------------------------------------------------------------
# Step counter = 137
# Controller output: {'fcu_oveTSup_u': np.float64(289.8344341750307), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0888584057308337), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.48
# -------------------------------------------------------------------
# Step counter = 138
# Controller output: {'fcu_oveTSup_u': np.float64(286.5593815750034), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.1604768920726854), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.49
# -------------------------------------------------------------------
# Step counter = 139
# Controller output: {'fcu_oveTSup_u': np.float64(294.5593815750034), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.49
# -------------------------------------------------------------------
# Step counter = 140
# Controller output: {'fcu_oveTSup_u': np.float64(297.22604824167007), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.13333333333333333), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.49
# -------------------------------------------------------------------
# Step counter = 141
# Controller output: {'fcu_oveTSup_u': np.float64(305.22604824167007), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.2592592592592593), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.50
# -------------------------------------------------------------------
# Step counter = 142
# Controller output: {'fcu_oveTSup_u': np.float64(297.22604824167007), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.10370370370370374), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.50
# -------------------------------------------------------------------
# Step counter = 143
# Controller output: {'fcu_oveTSup_u': np.float64(303.4482704638923), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.13497942386831277), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.50
# -------------------------------------------------------------------
# Step counter = 144
# Controller output: {'fcu_oveTSup_u': np.float64(306.114937130559), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.07443987197073618), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.51
# -------------------------------------------------------------------
# Step counter = 145
# Controller output: {'fcu_oveTSup_u': np.float64(298.114937130559), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.15246659553929787), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.51
# -------------------------------------------------------------------
# Step counter = 146
# Controller output: {'fcu_oveTSup_u': np.float64(295.4482704638923), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.51
# -------------------------------------------------------------------
# Step counter = 147
# Controller output: {'fcu_oveTSup_u': np.float64(296.3371593527812), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.17777777777777778), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.52
# -------------------------------------------------------------------
# Step counter = 148
# Controller output: {'fcu_oveTSup_u': np.float64(300.78160379722567), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.12592592592592594), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.52
# -------------------------------------------------------------------
# Step counter = 149
# Controller output: {'fcu_oveTSup_u': np.float64(299.89271490833676), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.03621399176954733), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.52
# -------------------------------------------------------------------
# Step counter = 150
# Controller output: {'fcu_oveTSup_u': np.float64(306.114937130559), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.026245999085505258), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.53
# -------------------------------------------------------------------
# Step counter = 151
# Controller output: {'fcu_oveTSup_u': np.float64(313.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.17596911039983745), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.53
# -------------------------------------------------------------------
# Step counter = 152
# Controller output: {'fcu_oveTSup_u': np.float64(311.3722222222222), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.16709738239992777), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.53
# -------------------------------------------------------------------
# Step counter = 153
# Controller output: {'fcu_oveTSup_u': np.float64(309.89074074074074), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.04078859804443642), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.54
# -------------------------------------------------------------------
# Step counter = 154
# Controller output: {'fcu_oveTSup_u': np.float64(311.8989711934156), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.18728002070122834), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.54
# -------------------------------------------------------------------
# Step counter = 155
# Controller output: {'fcu_oveTSup_u': np.float64(308.0105395518975), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.0), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.55
# -------------------------------------------------------------------
# Step counter = 156
# Controller output: {'fcu_oveTSup_u': np.float64(304.390359701265), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.11111111111111112), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.55
# -------------------------------------------------------------------
# Step counter = 157
# Controller output: {'fcu_oveTSup_u': np.float64(298.1681374790428), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.20740740740740743), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.55
# -------------------------------------------------------------------
# Step counter = 158
# Controller output: {'fcu_oveTSup_u': np.float64(291.94591525682057), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.40740740740740744), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.56
# -------------------------------------------------------------------
# Step counter = 159
# Controller output: {'fcu_oveTSup_u': np.float64(296.6579340886382), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6074074074074074), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.56
# -------------------------------------------------------------------
# Step counter = 160
# Controller output: {'fcu_oveTSup_u': np.float64(293.99126742197154), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6296296296296295), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.56
# -------------------------------------------------------------------
# Step counter = 161
# Controller output: {'fcu_oveTSup_u': np.float64(293.10237853308263), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8296296296296295), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.57
# -------------------------------------------------------------------
# Step counter = 162
# ...
# Step counter = 235
# Controller output: {'fcu_oveTSup_u': np.float64(307.470987654321), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.19492249923408267), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.82
# -------------------------------------------------------------------
# Step counter = 236
# Controller output: {'fcu_oveTSup_u': np.float64(305.550548696845), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.30716194384873097), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.83
# -------------------------------------------------------------------
# Step counter = 237
# Controller output: {'fcu_oveTSup_u': np.float64(311.41672763298277), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5071619438487309), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.83
# -------------------------------------------------------------------
# Step counter = 238
# Controller output: {'fcu_oveTSup_u': np.float64(307.7426264627682), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.35160638829317536), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.83
# -------------------------------------------------------------------
# Step counter = 239
# Controller output: {'fcu_oveTSup_u': np.float64(304.2117509751788), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4627174994042865), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.84
# -------------------------------------------------------------------
# Step counter = 240
# Controller output: {'fcu_oveTSup_u': np.float64(305.1006398640677), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4849397216265088), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.84
# -------------------------------------------------------------------
# Step counter = 241
# Controller output: {'fcu_oveTSup_u': np.float64(298.8784176418455), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5960508327376198), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.84
# -------------------------------------------------------------------
# Step counter = 242
# Controller output: {'fcu_oveTSup_u': np.float64(301.5450843085122), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7516063882931754), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.85
# -------------------------------------------------------------------
# Step counter = 243
# Controller output: {'fcu_oveTSup_u': np.float64(302.4339731974011), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9516063882931753), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.85
# -------------------------------------------------------------------
# Step counter = 244
# Controller output: {'fcu_oveTSup_u': np.float64(296.21175097517886), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8896028392414113), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.85
# -------------------------------------------------------------------
# Step counter = 245
# Controller output: {'fcu_oveTSup_u': np.float64(289.98952875295663), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.965511426582379), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.86
# -------------------------------------------------------------------
# Step counter = 246
# Controller output: {'fcu_oveTSup_u': np.float64(290.85645722353627), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9478914281294175), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.86
# -------------------------------------------------------------------
# Step counter = 247
# Controller output: {'fcu_oveTSup_u': np.float64(291.2417587660161), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8599396822941209), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.86
# -------------------------------------------------------------------
# Step counter = 248
# Controller output: {'fcu_oveTSup_u': np.float64(294.54450584401076), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6599396822941208), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.87
# -------------------------------------------------------------------
# Step counter = 249
# Controller output: {'fcu_oveTSup_u': np.float64(286.54450584401076), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5488285711830097), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.87
# -------------------------------------------------------------------
# Step counter = 250
# Controller output: {'fcu_oveTSup_u': np.float64(293.5006718613429), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7488285711830096), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.88
# -------------------------------------------------------------------
# Step counter = 251
# Controller output: {'fcu_oveTSup_u': np.float64(290.8340051946762), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9488285711830096), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.88
# -------------------------------------------------------------------
# Step counter = 252
# Controller output: {'fcu_oveTSup_u': np.float64(286.67044502163066), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9162761903943365), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.88
# -------------------------------------------------------------------
# Step counter = 253
# Controller output: {'fcu_oveTSup_u': np.float64(294.67044502163066), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8423756613301869), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.89
# -------------------------------------------------------------------
# Step counter = 254
# Controller output: {'fcu_oveTSup_u': np.float64(302.67044502163066), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7615837742201247), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.89
# -------------------------------------------------------------------
# Step counter = 255
# Controller output: {'fcu_oveTSup_u': np.float64(305.33711168829734), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9171393297756802), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.89
# -------------------------------------------------------------------
# Step counter = 256
# Controller output: {'fcu_oveTSup_u': np.float64(304.3650620490541), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9685710366417423), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.90
# -------------------------------------------------------------------
# Step counter = 257
# Controller output: {'fcu_oveTSup_u': np.float64(296.3650620490541), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9485713414759427), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.90
# -------------------------------------------------------------------
# Step counter = 258
# Controller output: {'fcu_oveTSup_u': np.float64(295.47617316016516), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7765078590897269), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.90
# -------------------------------------------------------------------
# Step counter = 259
# Controller output: {'fcu_oveTSup_u': np.float64(301.6983953823874), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7987300813119491), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.91
# -------------------------------------------------------------------
# Step counter = 260
# Controller output: {'fcu_oveTSup_u': np.float64(295.47617316016516), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7765078590897269), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.91
# -------------------------------------------------------------------
# Step counter = 261
# Controller output: {'fcu_oveTSup_u': np.float64(299.9206176046096), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.6653967479786157), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.91
# -------------------------------------------------------------------
# Step counter = 262
# Controller output: {'fcu_oveTSup_u': np.float64(291.9206176046096), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8653967479786158), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.92
# -------------------------------------------------------------------
# Step counter = 263
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8141093044325644), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.92
# -------------------------------------------------------------------
# Step counter = 264
# Controller output: {'fcu_oveTSup_u': np.float64(288.7055555555555), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9571232560480627), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.92
# -------------------------------------------------------------------
# Step counter = 265
# Controller output: {'fcu_oveTSup_u': np.float64(296.7055555555555), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8920547804658057), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.93
# -------------------------------------------------------------------
# Step counter = 266
# Controller output: {'fcu_oveTSup_u': np.float64(294.03888888888883), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8631354579848025), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.93
# -------------------------------------------------------------------
# Step counter = 267
# Controller output: {'fcu_oveTSup_u': np.float64(293.1499999999999), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7754236386565351), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.93
# -------------------------------------------------------------------
# Step counter = 268
# Controller output: {'fcu_oveTSup_u': np.float64(299.37222222222215), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.575423638656535), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.94
# -------------------------------------------------------------------
# Step counter = 269
# Controller output: {'fcu_oveTSup_u': np.float64(305.5944444444444), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7309791942120905), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.94
# -------------------------------------------------------------------
# Step counter = 270
# Controller output: {'fcu_oveTSup_u': np.float64(307.96481481481476), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.9309791942120904), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.94
# -------------------------------------------------------------------
# Step counter = 271
# Controller output: {'fcu_oveTSup_u': np.float64(299.96481481481476), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.8206527961413936), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.95
# -------------------------------------------------------------------
# Step counter = 272
# Controller output: {'fcu_oveTSup_u': np.float64(293.74259259259253), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.7049521747766395), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.95
# -------------------------------------------------------------------
# Step counter = 273
# Controller output: {'fcu_oveTSup_u': np.float64(289.2981481481481), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5049521747766395), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.95
# -------------------------------------------------------------------
# Step counter = 274
# Controller output: {'fcu_oveTSup_u': np.float64(287.84958847736624), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.3493966192210839), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.96
# -------------------------------------------------------------------
# Step counter = 275
# Controller output: {'fcu_oveTSup_u': np.float64(286.3388431641518), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.37161884144330615), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.96
# -------------------------------------------------------------------
# Step counter = 276
# Controller output: {'fcu_oveTSup_u': np.float64(291.2758954427679), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5271743969988616), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.97
# -------------------------------------------------------------------
# Step counter = 277
# Controller output: {'fcu_oveTSup_u': np.float64(288.28908787617064), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5938410636655282), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.97
# -------------------------------------------------------------------
# Step counter = 278
# Controller output: {'fcu_oveTSup_u': np.float64(285.15), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.4827299525544171), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.97
# -------------------------------------------------------------------
# Step counter = 279
# Controller output: {'fcu_oveTSup_u': np.float64(289.59444444444443), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5493966192210837), 'fcu_oveFan_activate': 1}
# =======retrain GP model=======
# Simulation time [elapsed days] = 0.98
# -------------------------------------------------------------------
# Step counter = 280
# Controller output: {'fcu_oveTSup_u': np.float64(296.2117283950617), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.5271743969988615), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.98
# -------------------------------------------------------------------
# Step counter = 281
# Controller output: {'fcu_oveTSup_u': np.float64(297.10061728395056), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.32717439699886147), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.98
# -------------------------------------------------------------------
# Step counter = 282
# Controller output: {'fcu_oveTSup_u': np.float64(290.8783950617283), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.26050773033219476), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.99
# -------------------------------------------------------------------
# Step counter = 283
# Controller output: {'fcu_oveTSup_u': np.float64(297.3530178326474), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.1049521747766392), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.99
# -------------------------------------------------------------------
# Step counter = 284
# Controller output: {'fcu_oveTSup_u': np.float64(289.3530178326474), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.16941787487591067), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 0.99
# -------------------------------------------------------------------
# Step counter = 285
# Controller output: {'fcu_oveTSup_u': np.float64(291.9294543514708), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.20523215270883927), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.00
# -------------------------------------------------------------------
# Step counter = 286
# Controller output: {'fcu_oveTSup_u': np.float64(291.71864637843146), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.18300993048661704), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.00
# -------------------------------------------------------------------
# Step counter = 287
# Controller output: {'fcu_oveTSup_u': np.float64(298.0999078919391), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.383009930486617), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.00
# -------------------------------------------------------------------
# Step counter = 288
# Controller output: {'fcu_oveTSup_u': np.float64(297.2110190030502), 'fcu_oveTSup_activate': 1, 'fcu_oveFan_u': np.float64(0.183009930486617), 'fcu_oveFan_activate': 1}
# Simulation time [elapsed days] = 1.01

# %%
def get_and_plot_results(testid, start_time, final_time):
    points = ['zon_reaTRooAir_y', 'fcu_oveTSup_u', 'fcu_oveFan_u', 'zon_weaSta_reaWeaTDryBul_y']
    args = {
        'point_names': points,
        'start_time': start_time, 
        'final_time': final_time
    }
    
    response = requests.put('{0}/results/{1}'.format(url, testid), json=args).json()
    
    if 'payload' not in response:
        print("Error: Could not retrieve data. Check if testid is still active.")
        return None
        
    df_res = pd.DataFrame(data=response['payload'])
    
    df_res = df_res.set_index('time')
    x_time = df_res.index / 3600. / 24.
    x_time = x_time - (start_time / 3600. / 24.)
    df_res['time'] = x_time
    

    plt.close('all')
    fig, axs = plt.subplots(4, 1, sharex=True, figsize=(10, 10))
    
    axs[0].plot(x_time, df_res['zon_reaTRooAir_y'] - 273.15, color='darkorange', linewidth=0.8, label='$T_z$')
    axs[0].set_ylabel('Operative\nTemp ($^\circ$C)')
    axs[0].legend(loc='upper right')
    axs[0].grid(True)

    axs[1].plot(x_time, df_res['zon_weaSta_reaWeaTDryBul_y'] - 273.15, color='green', linewidth=0.8, label='$T_{amb}$')
    axs[1].set_ylabel('Ambient\nTemp ($^\circ$C)')
    axs[1].legend(loc='upper right')
    axs[1].grid(True)

    axs[2].plot(x_time, df_res['fcu_oveTSup_u'] - 273.15, color='red', linewidth=0.8, label='$fcu_oveTSup_u$')
    axs[2].legend(loc='upper right')
    axs[2].grid(True)

    axs[3].plot(x_time, df_res['fcu_oveFan_u'], color='royalblue', linewidth=0.8, label='$fcu_oveFan_u$')
    axs[3].set_xlabel('Time (days)')
    axs[3].legend(loc='upper right')
    axs[3].grid(True)

    plt.tight_layout()
    plt.show()
    
    return df_res

start_in_seconds = start_time_days * 24 * 3600
final_in_seconds = start_in_seconds + (14 * 24 * 3600)

get_and_plot_results(testid=testid, start_time=start_in_seconds, final_time=final_in_seconds)
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\namng\AppData\Local\Temp\ipykernel_36736\137404845.py:33: SyntaxWarning: invalid escape sequence '\c'
#   axs[0].set_ylabel('Operative\nTemp ($^\circ$C)')
# C:\Users\namng\AppData\Local\Temp\ipykernel_36736\137404845.py:39: SyntaxWarning: invalid escape sequence '\c'
#   axs[1].set_ylabel('Ambient\nTemp ($^\circ$C)')
#          zon_reaTRooAir_y  fcu_oveTSup_u  fcu_oveFan_u  \
# time
# 3801600        295.310128     294.150000       0.00000
# 3801630        295.222125     293.150000       0.50000
# 3801660        295.117210     293.150000       0.50000
# 3801690        295.023884     293.150000       0.50000
# 3801720        294.940950     293.150000       0.50000
# ...                   ...            ...           ...
# 3888480        291.964908     297.211019       0.18301
# 3888510        291.933635     297.211019       0.18301
# 3888540        291.904954     297.211019       0.18301
# 3888570        291.878627     297.211019       0.18301
# 3888600        291.854438     297.211019       0.18301
#
#          zon_weaSta_reaWeaTDryBul_y      time
# time
# 3801600                  279.050000  0.000000
# 3801630                  279.025812  0.000347
# 3801660                  279.001625  0.000694
# 3801690                  278.977439  0.001042
# 3801720                  278.953254  0.001389
# ...                             ...       ...
# 3888480                  268.916667  1.005556
# 3888510                  268.908333  1.005903
# 3888540                  268.900000  1.006250
# 3888570                  268.891667  1.006597
# 3888600                  268.883333  1.006944
#
# [2901 rows x 5 columns]

# %%
ls_rmse = [t.cpu()*30 for t in ls_rmse]

# %%
plt.plot(ls_rmse[:1000])
plt.xlabel('Iteration (number of new data points)')
plt.grid()
plt.ylabel('RMSE (F)')
plt.title('Passive learning for GP model RMSE')
plt.show()

# %%
import os

df = pd.DataFrame(np.array(ls_rmse), columns=["RMSE_PL_GP"])

save_dir = 'results'                                       
os.makedirs(save_dir, exist_ok=True)                        

save_path = f"RMSE_PL_GP_ini{Ne_tr}_{const.ramp}.csv"                   
full_path = os.path.join(save_dir, save_path)               
df.to_csv(full_path, index=False)

# %%
np.mean(ls_rmse[:300])
# Out:
# np.float32(3.00661)

# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from sklearn.utils import resample
import constant as const

# %%
import warnings
warnings.filterwarnings("ignore")

url = "http://127.0.0.1:80"
testcase = 'bestest_air'
testid = \
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using:", device)
print("done")
# Out:
# Using: cuda
# done

# %%
testid = \
requests.post('{0}/testcases/{1}/select'.format(url,testcase)).json()['testid']
name = requests.get('{0}/name/{1}'.format(url, testid)).json()['payload']
print(name)
# Out:
# {'name': 'bestest_air'}

# %%
data = pd.read_csv(f'processed_uniform_low_step_5m_data.csv')
data.head()

T_zone = (data['zon_reaTRooAir_y'].values - 273.15) / 30.0
T_sup  = (data['fcu_oveTSup_u'].values - 273.15) / 40.0
fan  = data['fcu_oveFan_u'].values
T_out = (data['zon_weaSta_reaWeaTDryBul_y'].values - 273.15) / 10.0

pos_T_zone = T_zone[1:]
cur_T_zone = T_zone[:-1]
cur_T_sup = T_sup[:-1]
cur_fan = fan[:-1]
cur_T_out = T_out[:-1]

def to_tensor(x):
    return torch.tensor(x, dtype=torch.float32, device=device)

def data_split(Ns, Ne, x1, x2, x3, x4, x5):
    return (to_tensor(x1[Ns:Ne]).view(-1,1), to_tensor(x2[Ns:Ne]).view(-1,1),
            to_tensor(x3[Ns:Ne]).view(-1,1), to_tensor(x4[Ns:Ne]).view(-1,1), to_tensor(x5[Ns:Ne]).view(-1,1))

Ns_tr, Ne_tr = const.Ns_tr, const.Ne_tr  
Ns_t, Ne_t = const.Ns_t, const.Ne_t 

cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr, pos_T_zone_tr = data_split(Ns_tr, Ne_tr, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)
cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t, pos_T_zone_t = data_split(Ns_t, Ne_t, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)

X_tr = torch.cat((cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr), dim=1)
y_tr = pos_T_zone_tr.squeeze(-1)  

X_t = torch.cat((cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t), dim=1)
y_t = pos_T_zone_t.squeeze(-1)

class NN(nn.Module):
    def __init__(self, input_dim, hidden_dim=const.hidden_dim, output_dim=2):
        super().__init__()
        self.net = nn.Sequential(nn.Linear(input_dim, hidden_dim),
                                 nn.ReLU(),
                                 nn.Linear(hidden_dim, output_dim)
                                 )
    def forward(self, x):
        return self.net(x)

nx = 1
nu = 2
no = 1

# %%
criterion = nn.MSELoss()
def train_nn(model, X, y, epochs=20, save=False, save_path='model_AL_NN.pth'):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=const.lr, weight_decay=1e-3)

    for epoch in range(epochs):
        optimizer.zero_grad()
        preds = model(X).squeeze(-1)
        loss = criterion(y, preds)
        loss.backward()
        optimizer.step()

    if save:
        torch.save(model.state_dict(), save_path)
    return model

def boot_NN_ls(X_tr, y_tr, num_bootstrap=10, epochs=20):
    model_ls = []
    bootstrap_data= []
    save_path_ls = []
    for i in range(num_bootstrap):
        X_boot, y_boot = resample(
            X_tr, y_tr,
            replace=True,
            n_samples=len(X_tr),
            random_state=i)
        bootstrap_data.append((X_boot, y_boot))
    for i, (X_i, y_i) in enumerate(bootstrap_data):
        torch.manual_seed(i*50)
        save_path_i = f'checkpoints/model_MLLC_bootstrap_{i}.pth'
        model_NN = NN(input_dim=nx+nu+no, hidden_dim=const.hidden_dim, output_dim=nx).to(device)
        if i > 0:
            model_NN.load_state_dict(torch.load(save_path_i))
        trained_NN = train_nn(model_NN, X_i, y_i, epochs=epochs)

        torch.save(trained_NN.state_dict(), save_path_i)
        model_ls.append(trained_NN)
        save_path_ls.append(save_path_i)
        
    return model_ls, save_path_ls

save_path = 'checkpoints/model_AL_MLLC_NN.pth'

# %%
def evaluate_NN(X_t, y_t, save_path='checkpoints/model_AL_MLLC_NN.pth'):
    model = NN(input_dim=nx+nu+no, hidden_dim=const.hidden_dim, output_dim=nx).to(device)
    model.load_state_dict(torch.load(save_path, map_location=device))
    model.to(device)
    model.eval()
    with torch.no_grad():
        observed_pred = model(X_t).squeeze(-1)
        rmse = torch.sqrt(torch.mean((observed_pred - y_t)**2))
    return rmse

# %%
def acqui_func(main_NN, model_ls, U_grid, X_0, X_out, plot=False):
    """
    Gradient-based Expected Model Change (BMLLC)
    main_NN  : main neural network (nn.Module)
    model_ls : committee models (list of nn.Module)
    U_grid   : tensor [N_points, 2] (normalized [0,1])
    X_0      : tensor [1, nx] (normalized)
    X_out    : tensor [1, nx] (normalized)
    """
    main_NN.to('cpu')
    main_NN.eval()
    for m in model_ls:
        m.to('cpu')
        m.eval()

    num_points = U_grid.shape[0]
    scores = torch.zeros(num_points)

    for i in range(num_points):
        u = U_grid[i:i+1] 
        Z = torch.cat((X_0, u, X_out), dim=1)
        fx = main_NN(Z)
        grad_norm_sum = 0.0

        for model_i in model_ls:
            y_comm = model_i(Z)
            loss = torch.nn.functional.mse_loss(fx, y_comm)
            last_layer_params = list(main_NN.net[-1].parameters())
            grads = torch.autograd.grad(
                loss,
                last_layer_params,
                retain_graph=True,
                allow_unused=True
            )
            grad_norm = torch.sqrt(sum(torch.sum(g ** 2) for g in grads if g is not None))
            grad_norm_sum += grad_norm

        scores[i] = grad_norm_sum / len(model_ls)
        
    ind = torch.argmax(scores)
    U_optim = U_grid[ind]

    if plot:
        u1_vals = torch.unique(U_grid[:, 0]).cpu().numpy()
        u2_vals = torch.unique(U_grid[:, 1]).cpu().numpy()

        n1 = len(u1_vals)
        n2 = len(u2_vals)
        s_map = np.zeros((n2, n1))

        for k in range(len(scores)):
            i = np.where(u1_vals == U_grid[k, 0].cpu().numpy())[0][0]
            j = np.where(u2_vals == U_grid[k, 1].cpu().numpy())[0][0]
            s_map[j, i] = scores[k].item()

        plt.figure(figsize=(6,5))
        cp = plt.imshow(
            s_map,
            extent=[u1_vals.min(), u1_vals.max(),
                    u2_vals.min(), u2_vals.max()],
            origin="lower",
            aspect="auto"
        )

        print("Max score:", scores[ind].item())

        plt.colorbar(cp, label="Expected Model Change (Score)")
        plt.scatter(
            U_optim[0].cpu(),
            U_optim[1].cpu(),
            c="red",
            marker="x",
            s=100)
        plt.xlabel("u1 (Supply)")
        plt.ylabel("u2 (Airflow)")
        plt.title("BMLLC Acquisition Landscape")
        plt.show()
    return U_optim


class MPC:
    def __init__(self, main_NN, device='cpu'):
        self.device = device
        self.main_NN = main_NN
        self.main_NN.eval()

    def mpc_grid_search(self, u0_1, u0_2, X_0, X_out, model_ls, n_grid, plot=True):
        X_0_norm = torch.tensor(X_0, dtype=torch.float32, device=self.device).view(1, -1) / 30.0
        x_out_norm = torch.tensor(X_out, dtype=torch.float32, device=self.device).view(1, -1) / 10.0

        u1_vals = torch.linspace(max(u0_1-const.ramp, 0.3), min(u0_1+const.ramp, 1.0), n_grid)
        u2_vals = torch.linspace(max(u0_2-const.ramp, 0.0), min(u0_2+const.ramp, 1.0), n_grid)
        
        u1_vals = u1_vals[~torch.isclose(u1_vals, torch.tensor(u0_1))]
        u2_vals = u2_vals[~torch.isclose(u2_vals, torch.tensor(u0_2))]

        U_grid = torch.cartesian_prod(u1_vals, u2_vals)
        
        best_u = acqui_func(self.main_NN, model_ls, U_grid, X_0_norm, x_out_norm, plot=plot)
        
        return best_u, {
            'fcu_oveTSup_u': float(best_u[0] * 40 + 273.15),
            'fcu_oveTSup_activate': 1,
            'fcu_oveFan_u': float(best_u[1]),
            'fcu_oveFan_activate': 1
        }

# %%
y = requests.put('{0}/scenario/{1}'.format(url, testid), 
                 json={'time_period':'typical_heat_day',
                       'electricity_price':'dynamic'}).json()['payload']['time_period']
requests.put('{0}/step/{1}'.format(url, testid), json={'step':const.step*60})
start_time_days = y['time']/3600/24

# %%
counter = 0
u0_1 = 0.5
u0_2 = 0.5
u = {'fcu_oveTSup_u': u0_1 * 40 + 273.15,
    'fcu_oveTSup_activate': 1,
    'fcu_oveFan_u': u0_2,
    'fcu_oveFan_activate': 1}
print('Simulation time [elapsed days] = {:.2f}'.format((y['time']/3600/24 - start_time_days)))
y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  
X_tr_new = X_tr
y_tr_new = y_tr

save_path_ini = 'checkpoints/model_ini_AL_NN.pth'
main_NN = NN(input_dim=nx+nu+no, hidden_dim=const.hidden_dim, output_dim=nx).to(device)
main_NN.load_state_dict(torch.load(save_path_ini, map_location=device))
main_NN = train_nn(main_NN, X_tr, y_tr, epochs=const.epoch_ini, save=True, save_path=save_path)

ls_rmse = [evaluate_NN(X_t, y_t, save_path=save_path)]

model_ls, save_boost_path = boot_NN_ls(X_tr, y_tr, num_bootstrap=const.N_bootstrap, epochs=const.epoch_ini)
n_grid = 10
# Out:
# Simulation time [elapsed days] = 0.00

# %%
print("Initial RMSE:", ls_rmse[-1])
# Out:
# Initial RMSE: tensor(0.2991, device='cuda:0')

# %%
number_of_data = 10
count_data = 1
while y:
    x0 = y['zon_reaTRooAir_y']-273.15
    x_out = (y['zon_weaSta_reaWeaTDryBul_y']-273.15)

    print('-------------------------------------------------------------------')
    print('Step counter =', counter)
    counter += 1
    mpc_controller = MPC(main_NN)
    best_u, u = mpc_controller.mpc_grid_search(u0_1=u0_1, u0_2=u0_2, X_0=x0, X_out=x_out, 
                                               model_ls=model_ls, n_grid=n_grid, plot=False)
    
    print('Selected control (normalized):', best_u.cpu().numpy())
    y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  
    
    cur = to_tensor(x0).view(-1,1)/30.0
    T_sup_add = to_tensor((u['fcu_oveTSup_u']-273.15)/40.0).view(-1,1)
    fan_add = to_tensor(u['fcu_oveFan_u']).view(-1,1)
    pos_add = to_tensor(y['zon_reaTRooAir_y']-273.15).view(-1,1)/30.0
    T_out_add = to_tensor((y['zon_weaSta_reaWeaTDryBul_y']-273.15)/10.0).view(-1,1)

    X_tr_n, y_tr_n = torch.cat((cur, T_sup_add, fan_add, T_out_add), dim=1), pos_add.squeeze(-1)   
    X_tr_new, y_tr_new = torch.cat((X_tr_new, X_tr_n), dim=0), torch.cat((y_tr_new, y_tr_n), dim=0)
    
    if count_data == number_of_data:
        main_NN = train_nn(main_NN, X_tr_new, y_tr_new, epochs=const.epoch_onl, save=True, save_path=save_path)
        model_ls, save_boost_path = boot_NN_ls(X_tr_new, y_tr_new, num_bootstrap=const.N_bootstrap, epochs=const.epoch_onl)
        count_data = 0
    count_data += 1
    rmse = evaluate_NN(X_t, y_t, save_path=save_path)
    ls_rmse.append(rmse)

    u0_1 = (u['fcu_oveTSup_u'] - 273.15) / 40.0
    u0_2 = u['fcu_oveFan_u']

    if counter > const.num_count:
        break
# Out:
# -------------------------------------------------------------------
# Step counter = 0
# Selected control (normalized): [0.7 0.3]
# -------------------------------------------------------------------
# Step counter = 1
# Selected control (normalized): [0.89999986 0.10000001]
# -------------------------------------------------------------------
# Step counter = 2
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 3
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 4
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 5
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 6
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 7
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 8
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 9
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 10
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 11
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 12
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 13
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 14
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 15
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 16
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 17
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 18
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 19
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 20
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 21
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 22
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 23
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 24
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 25
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 26
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 27
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 28
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 29
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 30
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 31
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 32
# Selected control (normalized): [1. 0.]
# -------------------------------------------------------------------
# Step counter = 33
# Selected control (normalized): [0.9777778 0.2      ]
# -------------------------------------------------------------------
# Step counter = 34
# Selected control (normalized): [1.0000000e+00 2.9802323e-09]
# -------------------------------------------------------------------
# Step counter = 35
# Selected control (normalized): [0.9777778  0.02222222]
# -------------------------------------------------------------------
# Step counter = 36
# Selected control (normalized): [1.         0.22222222]
# -------------------------------------------------------------------
# Step counter = 37
# Selected control (normalized): [0.9777778  0.42222223]
# -------------------------------------------------------------------
# Step counter = 38
# Selected control (normalized): [1.         0.62222224]
# -------------------------------------------------------------------
# Step counter = 39
# Selected control (normalized): [0.9777778  0.82222223]
# -------------------------------------------------------------------
# Step counter = 40
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 41
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 42
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 43
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 44
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 45
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 46
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 47
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 48
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 49
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 50
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 51
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 52
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 53
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 54
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 55
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 56
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 57
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 58
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 59
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 60
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 61
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 62
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 63
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 64
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 65
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 66
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 67
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 68
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 69
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 70
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 71
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 72
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 73
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 74
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 75
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 76
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 77
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 78
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 79
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 80
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 81
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 82
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 83
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 84
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 85
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 86
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 87
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 88
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 89
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 90
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 91
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 92
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 93
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 94
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 95
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 96
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 97
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 98
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 99
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 100
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 101
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 102
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 103
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 104
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 105
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 106
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 107
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 108
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 109
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 110
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 111
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 112
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 113
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 114
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 115
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 116
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 117
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 118
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 119
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 120
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 121
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 122
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 123
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 124
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 125
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 126
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 127
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 128
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 129
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 130
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 131
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 132
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 133
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 134
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 135
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 136
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 137
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 138
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 139
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 140
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 141
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 142
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 143
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 144
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 145
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 146
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 147
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 148
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 149
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 150
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 151
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 152
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 153
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 154
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 155
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 156
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 157
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 158
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 159
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 160
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 161
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 162
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 163
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 164
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 165
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 166
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 167
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 168
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 169
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 170
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 171
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 172
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 173
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 174
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 175
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 176
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 177
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 178
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 179
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 180
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 181
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 182
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 183
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 184
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 185
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 186
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 187
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 188
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 189
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 190
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 191
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 192
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 193
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 194
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 195
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 196
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 197
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 198
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 199
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 200
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 201
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 202
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 203
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 204
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 205
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 206
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 207
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 208
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 209
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 210
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 211
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 212
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 213
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 214
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 215
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 216
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 217
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 218
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 219
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 220
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 221
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 222
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 223
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 224
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 225
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 226
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 227
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 228
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 229
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 230
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 231
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 232
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 233
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 234
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 235
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 236
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 237
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 238
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 239
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 240
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 241
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 242
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 243
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 244
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 245
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 246
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 247
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 248
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 249
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 250
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 251
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 252
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 253
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 254
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 255
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 256
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 257
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 258
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 259
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 260
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 261
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 262
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 263
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 264
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 265
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 266
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 267
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 268
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 269
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 270
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 271
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 272
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 273
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 274
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 275
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 276
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 277
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 278
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 279
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 280
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 281
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 282
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 283
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 284
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 285
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 286
# Selected control (normalized): [1. 1.]
# -------------------------------------------------------------------
# Step counter = 287
# Selected control (normalized): [0.9777778 0.9777778]
# -------------------------------------------------------------------
# Step counter = 288
# Selected control (normalized): [1. 1.]

# %%
def get_and_plot_results(testid, start_time, final_time):
    points = ['zon_reaTRooAir_y', 'fcu_oveTSup_u', 'fcu_oveFan_u', 'zon_weaSta_reaWeaTDryBul_y']
    args = {
        'point_names': points,
        'start_time': start_time, 
        'final_time': final_time
    }
    
    response = requests.put('{0}/results/{1}'.format(url, testid), json=args).json()
    
    if 'payload' not in response:
        print("Error: Could not retrieve data. Check if testid is still active.")
        return None
        
    df_res = pd.DataFrame(data=response['payload'])
    
    df_res = df_res.set_index('time')
    x_time = df_res.index / 3600. / 24.
    x_time = x_time - (start_time / 3600. / 24.)
    df_res['time'] = x_time
    

    plt.close('all')
    fig, axs = plt.subplots(4, 1, sharex=True, figsize=(10, 10))
    
    axs[0].plot(x_time, df_res['zon_reaTRooAir_y'] - 273.15, color='darkorange', linewidth=0.8, label='$T_z$')
    axs[0].set_ylabel('Operative\nTemp ($^\circ$C)')
    axs[0].legend(loc='upper right')
    axs[0].grid(True)

    axs[1].plot(x_time, df_res['zon_weaSta_reaWeaTDryBul_y'] - 273.15, color='green', linewidth=0.8, label='$T_{amb}$')
    axs[1].set_ylabel('Ambient\nTemp ($^\circ$C)')
    axs[1].legend(loc='upper right')
    axs[1].grid(True)

    axs[2].plot(x_time, df_res['fcu_oveTSup_u'] - 273.15, color='red', linewidth=0.8, label='$fcu_oveTSup_u$')
    axs[2].legend(loc='upper right')
    axs[2].grid(True)

    axs[3].plot(x_time, df_res['fcu_oveFan_u'], color='royalblue', linewidth=0.8, label='$fcu_oveFan_u$')
    axs[3].set_xlabel('Time (days)')
    axs[3].legend(loc='upper right')
    axs[3].grid(True)

    plt.tight_layout()
    plt.show()
    
    return df_res

start_in_seconds = start_time_days * 24 * 3600
final_in_seconds = start_in_seconds + (14 * 24 * 3600)

get_and_plot_results(testid=testid, start_time=start_in_seconds, final_time=final_in_seconds)
# Out:
#          zon_reaTRooAir_y  fcu_oveTSup_u  fcu_oveFan_u  \
# time
# 3801600        295.310128     294.150000           0.0
# 3801630        295.222125     293.150000           0.5
# 3801660        295.117210     293.150000           0.5
# 3801690        295.023884     293.150000           0.5
# 3801720        294.940950     293.150000           0.5
# ...                   ...            ...           ...
# 3888480        306.962558     313.149994           1.0
# 3888510        306.987200     313.149994           1.0
# 3888540        307.007236     313.149994           1.0
# 3888570        307.023531     313.149994           1.0
# 3888600        307.036781     313.149994           1.0
#
#          zon_weaSta_reaWeaTDryBul_y      time
# time
# 3801600                  279.050000  0.000000
# 3801630                  279.025812  0.000347
# 3801660                  279.001625  0.000694
# 3801690                  278.977439  0.001042
# 3801720                  278.953254  0.001389
# ...                             ...       ...
# 3888480                  268.916667  1.005556
# 3888510                  268.908333  1.005903
# 3888540                  268.900000  1.006250
# 3888570                  268.891667  1.006597
# 3888600                  268.883333  1.006944
#
# [2901 rows x 5 columns]

# %%
ls_rmse = [r.item()*30 for r in ls_rmse]    
plt.plot(ls_rmse)
plt.xlabel('Iteration (number of new data points)')
plt.grid()
plt.ylabel('RMSE (F)')
plt.title(f'Active learning RMSE (ini = {Ne_tr} points)')
plt.show()
import os
save_dir = 'results'
os.makedirs(save_dir, exist_ok=True)

df = pd.DataFrame(np.array(ls_rmse), columns=["RMSE_MLLC_NN"])

save_path = f"RMSE_MLLC_NN_ini{Ne_tr}_lr{const.lr}_ramp{const.ramp}.csv"                   
full_path = os.path.join(save_dir, save_path)               
df.to_csv(full_path, index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

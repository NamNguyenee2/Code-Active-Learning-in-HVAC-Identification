# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from scipy.spatial.distance import cdist
import constant as const

# %%
import warnings
warnings.filterwarnings("ignore")

url = "http://127.0.0.1:80"
testcase = 'bestest_air'
testid = \
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using:", device)
print("done")
# Out:
# Using: cuda
# done

# %%
testid = \
requests.post('{0}/testcases/{1}/select'.format(url,testcase)).json()['testid']
name = requests.get('{0}/name/{1}'.format(url, testid)).json()['payload']
print(name)
# Out:
# {'name': 'bestest_air'}

# %%
data = pd.read_csv(f'processed_uniform_low_step_5m_data.csv')
data.head()

T_zone = (data['zon_reaTRooAir_y'].values - 273.15) / 30.0
T_sup  = (data['fcu_oveTSup_u'].values - 273.15) / 40.0
fan  = data['fcu_oveFan_u'].values
T_out = (data['zon_weaSta_reaWeaTDryBul_y'].values - 273.15) / 10.0

pos_T_zone = T_zone[1:]
cur_T_zone = T_zone[:-1]
cur_T_sup = T_sup[:-1]
cur_fan = fan[:-1]
cur_T_out = T_out[:-1]

def to_tensor(x):
    return torch.tensor(x, dtype=torch.float32, device=device)

def data_split(Ns, Ne, x1, x2, x3, x4, x5):
    return (to_tensor(x1[Ns:Ne]).view(-1,1), to_tensor(x2[Ns:Ne]).view(-1,1),
            to_tensor(x3[Ns:Ne]).view(-1,1), to_tensor(x4[Ns:Ne]).view(-1,1), to_tensor(x5[Ns:Ne]).view(-1,1))

Ns_tr, Ne_tr = const.Ns_tr, const.Ne_tr  
Ns_t, Ne_t = const.Ns_t, const.Ne_t 

cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr, pos_T_zone_tr = data_split(Ns_tr, Ne_tr, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)
cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t, pos_T_zone_t = data_split(Ns_t, Ne_t, cur_T_zone, cur_T_sup, cur_fan, cur_T_out, pos_T_zone)

X_tr = torch.cat((cur_T_zone_tr, cur_T_sup_tr, cur_fan_tr, cur_T_out_tr), dim=1)
y_tr = pos_T_zone_tr.squeeze(-1)  

X_t = torch.cat((cur_T_zone_t, cur_T_sup_t, cur_fan_t, cur_T_out_t), dim=1)
y_t = pos_T_zone_t.squeeze(-1)

# %%
class NN(nn.Module):
    def __init__(self, input_dim, hidden_dim=const.hidden_dim, output_dim=1, dropout_rate=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(hidden_dim, output_dim)
        )
    def forward(self, x):
        return self.net(x)

criterion = nn.MSELoss()
def train_nn(model, X, y, epochs=20, save_path='model_AL_MCD_NN.pth'):
    optimizer = torch.optim.Adam(model.parameters(), lr=const.lr, weight_decay=1e-3)
    for epoch in range(epochs):
        optimizer.zero_grad()
        preds = model(X).squeeze(-1)
        loss = criterion(preds, y)
        loss.backward()
        optimizer.step()

    torch.save(model.state_dict(), save_path)
    return model

nx = 1
nu = 2
no = 1
save_ini_path = 'checkpoints/model_ini_AL_NN.pth'
save_path = 'checkpoints/model_AL_MCD_NN.pth'

model_NN = NN(input_dim=nx+nu+no, hidden_dim=const.hidden_dim, output_dim=nx).to(device)
old_sd = torch.load(save_ini_path, map_location=device)
new_sd = {('net.3' + k[5:] if k.startswith('net.2') else k): v for k, v in old_sd.items()}
model_NN.load_state_dict(new_sd)
# Out:
# <All keys matched successfully>

# %%
def evaluate_NN(X_t, y_t, save_path='checkpoints/model_AL_MCD_NN.pth'):
    model = NN(input_dim=nx+nu+no, hidden_dim=const.hidden_dim, output_dim=nx).to(device)
    model.load_state_dict(torch.load(save_path, map_location=device))
    model.eval()

    with torch.no_grad():
        observed_pred = model(X_t).squeeze(-1)
        rmse = torch.sqrt(torch.mean((observed_pred - y_t)**2))
    return rmse

# %%
def acqui_func(model, U_grid, X_0, X_out, T=50, plot=False):
    N = U_grid.shape[0]
    X_cands = torch.cat([X_0.expand(N, -1), U_grid, X_out.expand(N, -1)], dim=1)

    model.train()
    with torch.no_grad():
        preds = torch.stack(
            [model(X_cands).squeeze(-1) for _ in range(T)], dim=0
        )

    scores = preds.var(dim=0).cpu().numpy()

    ind     = int(np.argmax(scores))
    U_optim = U_grid[ind]

    if plot:
        u1_vals = torch.unique(U_grid[:, 0]).cpu().numpy()
        u2_vals = torch.unique(U_grid[:, 1]).cpu().numpy()
        s_map   = np.zeros((len(u2_vals), len(u1_vals)))
        for k in range(N):
            i = np.where(u1_vals == U_grid[k, 0].cpu().numpy())[0][0]
            j = np.where(u2_vals == U_grid[k, 1].cpu().numpy())[0][0]
            s_map[j, i] = scores[k]
        plt.figure(figsize=(6, 5))
        cp = plt.imshow(s_map,
                        extent=[u1_vals.min(), u1_vals.max(),
                                u2_vals.min(), u2_vals.max()],
                        origin="lower", aspect="auto")
        plt.colorbar(cp, label="MCD Acquisition Score")
        plt.scatter(U_optim[0].cpu(), U_optim[1].cpu(), c="red", marker="x", s=100)
        plt.xlabel("u1 (Supply)")
        plt.ylabel("u2 (Airflow)")
        plt.title("MCD Acquisition Landscape")
        plt.show()

    return U_optim


class MPC:
    def __init__(self, models, device=device):
        self.device = device
        self.models = models

    def mpc_grid_search(self, X_0, X_out, u0_1, u0_2, n_grid, plot=True):
        X_0_norm   = torch.tensor(X_0, dtype=torch.float32, device=self.device).view(1, -1) / 30.0
        x_out_norm = torch.tensor(X_out, dtype=torch.float32, device=self.device).view(1, -1) / 10.0
        u1_vals    = torch.linspace(max(u0_1-const.ramp, 0.3), min(u0_1+const.ramp, 1.0), n_grid, device=self.device)
        u2_vals    = torch.linspace(max(u0_2-const.ramp, 0.0), min(u0_2+const.ramp, 1.0), n_grid, device=self.device)
        U_grid     = torch.cartesian_prod(u1_vals, u2_vals)

        best_u = acqui_func(self.models, U_grid, X_0_norm, x_out_norm, plot=plot)

        return best_u, {
            'fcu_oveTSup_u':        float(best_u[0] * 40 + 273.15),
            'fcu_oveTSup_activate': 1,
            'fcu_oveFan_u':         float(best_u[1]),
            'fcu_oveFan_activate':  1
        }

# %%
y = requests.put('{0}/scenario/{1}'.format(url, testid), 
                 json={'time_period':'typical_heat_day',
                       'electricity_price':'dynamic'}).json()['payload']['time_period']
requests.put('{0}/step/{1}'.format(url, testid), json={'step':const.step*60})
start_time_days = y['time']/3600/24

# %%
counter = 0
u0_1 = 0.5
u0_2 = 0.5
u = {'fcu_oveTSup_u': u0_1 * 40 + 273.15,
    'fcu_oveTSup_activate': 1,
    'fcu_oveFan_u': u0_2,
    'fcu_oveFan_activate': 1}
x_ref = 25
print('Simulation time [elapsed days] = {:.2f}'.format((y['time']/3600/24 - start_time_days)))
y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  
X_tr_new = X_tr
y_tr_new = y_tr
trained_nn = train_nn(model=model_NN, X=X_tr_new, y=y_tr_new, epochs=const.epoch_ini, save_path=save_path)
ls_rmse = [evaluate_NN(X_t, y_t, save_path=save_path)]
n_grid = 10
count = 0
# Out:
# Simulation time [elapsed days] = 0.00

# %%
while y:
    x0 = y['zon_reaTRooAir_y']-273.15
    x_out = (y['zon_weaSta_reaWeaTDryBul_y']-273.15)
    print('-------------------------------------------------------------------')
    print('Step counter =', counter)
    counter += 1
    mpc_controller = MPC(trained_nn)
    if count < 5:
        plot = True
        count += 1
    if count >= 5:
        plot = False
    best_u, u = mpc_controller.mpc_grid_search(X_0=x0, X_out=x_out, u0_1=u0_1, u0_2=u0_2, n_grid=n_grid, plot=plot)
    y = requests.post('{0}/advance/{1}'.format(url, testid), json=u).json()['payload']  
    
    cur = to_tensor(x0).view(-1,1)/30.0
    T_sup_add = to_tensor((u['fcu_oveTSup_u']-273.15)/40.0).view(-1,1)
    fan_add = to_tensor(u['fcu_oveFan_u']).view(-1,1)
    pos_add = to_tensor(y['zon_reaTRooAir_y']-273.15).view(-1,1)/30.0
    T_out_add = to_tensor((y['zon_weaSta_reaWeaTDryBul_y']-273.15)/10.0).view(-1,1)
    X_tr_n = torch.cat((cur, T_sup_add, fan_add, T_out_add), dim=1)
    y_tr_n = pos_add.squeeze(-1)   

    X_tr_new = torch.cat((X_tr_new, X_tr_n), dim=0)
    y_tr_new = torch.cat((y_tr_new, y_tr_n), dim=0)
    
    if const.count_data == const.number_of_data:
        trained_nn = train_nn(model=trained_nn, X=X_tr_new, y=y_tr_new, epochs=const.epoch_onl, save_path=save_path)
        const.count_data = 0
        
    const.count_data += 1
    rmse = evaluate_NN(X_t, y_t, save_path=save_path)
    ls_rmse.append(rmse)

    u0_1 = (u['fcu_oveTSup_u']-273.15)/ 40.0
    u0_2 = u['fcu_oveFan_u']

    if counter > const.num_count:
        break
# Out:
# -------------------------------------------------------------------
# Step counter = 0
# -------------------------------------------------------------------
# Step counter = 1
# -------------------------------------------------------------------
# Step counter = 2
# -------------------------------------------------------------------
# Step counter = 3
# -------------------------------------------------------------------
# Step counter = 4
# -------------------------------------------------------------------
# Step counter = 5
# -------------------------------------------------------------------
# Step counter = 6
# -------------------------------------------------------------------
# Step counter = 7
# -------------------------------------------------------------------
# Step counter = 8
# -------------------------------------------------------------------
# Step counter = 9
# -------------------------------------------------------------------
# Step counter = 10
# -------------------------------------------------------------------
# Step counter = 11
# -------------------------------------------------------------------
# Step counter = 12
# -------------------------------------------------------------------
# Step counter = 13
# -------------------------------------------------------------------
# Step counter = 14
# -------------------------------------------------------------------
# Step counter = 15
# -------------------------------------------------------------------
# Step counter = 16
# -------------------------------------------------------------------
# Step counter = 17
# -------------------------------------------------------------------
# Step counter = 18
# -------------------------------------------------------------------
# Step counter = 19
# -------------------------------------------------------------------
# Step counter = 20
# -------------------------------------------------------------------
# Step counter = 21
# -------------------------------------------------------------------
# Step counter = 22
# -------------------------------------------------------------------
# Step counter = 23
# -------------------------------------------------------------------
# Step counter = 24
# -------------------------------------------------------------------
# Step counter = 25
# -------------------------------------------------------------------
# Step counter = 26
# -------------------------------------------------------------------
# Step counter = 27
# -------------------------------------------------------------------
# Step counter = 28
# -------------------------------------------------------------------
# Step counter = 29
# -------------------------------------------------------------------
# Step counter = 30
# -------------------------------------------------------------------
# Step counter = 31
# -------------------------------------------------------------------
# Step counter = 32
# -------------------------------------------------------------------
# Step counter = 33
# -------------------------------------------------------------------
# Step counter = 34
# -------------------------------------------------------------------
# Step counter = 35
# -------------------------------------------------------------------
# Step counter = 36
# -------------------------------------------------------------------
# Step counter = 37
# -------------------------------------------------------------------
# Step counter = 38
# -------------------------------------------------------------------
# Step counter = 39
# -------------------------------------------------------------------
# Step counter = 40
# -------------------------------------------------------------------
# Step counter = 41
# -------------------------------------------------------------------
# Step counter = 42
# -------------------------------------------------------------------
# Step counter = 43
# -------------------------------------------------------------------
# Step counter = 44
# -------------------------------------------------------------------
# Step counter = 45
# -------------------------------------------------------------------
# Step counter = 46
# -------------------------------------------------------------------
# Step counter = 47
# -------------------------------------------------------------------
# Step counter = 48
# -------------------------------------------------------------------
# Step counter = 49
# -------------------------------------------------------------------
# Step counter = 50
# -------------------------------------------------------------------
# Step counter = 51
# -------------------------------------------------------------------
# Step counter = 52
# -------------------------------------------------------------------
# Step counter = 53
# -------------------------------------------------------------------
# Step counter = 54
# -------------------------------------------------------------------
# Step counter = 55
# -------------------------------------------------------------------
# Step counter = 56
# -------------------------------------------------------------------
# Step counter = 57
# -------------------------------------------------------------------
# Step counter = 58
# -------------------------------------------------------------------
# Step counter = 59
# -------------------------------------------------------------------
# Step counter = 60
# -------------------------------------------------------------------
# Step counter = 61
# -------------------------------------------------------------------
# Step counter = 62
# -------------------------------------------------------------------
# Step counter = 63
# -------------------------------------------------------------------
# Step counter = 64
# -------------------------------------------------------------------
# Step counter = 65
# -------------------------------------------------------------------
# Step counter = 66
# -------------------------------------------------------------------
# Step counter = 67
# -------------------------------------------------------------------
# Step counter = 68
# -------------------------------------------------------------------
# Step counter = 69
# -------------------------------------------------------------------
# Step counter = 70
# -------------------------------------------------------------------
# Step counter = 71
# -------------------------------------------------------------------
# Step counter = 72
# -------------------------------------------------------------------
# Step counter = 73
# -------------------------------------------------------------------
# Step counter = 74
# -------------------------------------------------------------------
# Step counter = 75
# -------------------------------------------------------------------
# Step counter = 76
# -------------------------------------------------------------------
# Step counter = 77
# -------------------------------------------------------------------
# Step counter = 78
# -------------------------------------------------------------------
# Step counter = 79
# -------------------------------------------------------------------
# Step counter = 80
# -------------------------------------------------------------------
# Step counter = 81
# -------------------------------------------------------------------
# Step counter = 82
# -------------------------------------------------------------------
# Step counter = 83
# -------------------------------------------------------------------
# Step counter = 84
# -------------------------------------------------------------------
# Step counter = 85
# -------------------------------------------------------------------
# Step counter = 86
# -------------------------------------------------------------------
# Step counter = 87
# -------------------------------------------------------------------
# Step counter = 88
# -------------------------------------------------------------------
# Step counter = 89
# -------------------------------------------------------------------
# Step counter = 90
# -------------------------------------------------------------------
# Step counter = 91
# -------------------------------------------------------------------
# Step counter = 92
# -------------------------------------------------------------------
# Step counter = 93
# -------------------------------------------------------------------
# Step counter = 94
# -------------------------------------------------------------------
# Step counter = 95
# -------------------------------------------------------------------
# Step counter = 96
# -------------------------------------------------------------------
# Step counter = 97
# -------------------------------------------------------------------
# Step counter = 98
# -------------------------------------------------------------------
# Step counter = 99
# -------------------------------------------------------------------
# Step counter = 100
# -------------------------------------------------------------------
# Step counter = 101
# -------------------------------------------------------------------
# Step counter = 102
# -------------------------------------------------------------------
# Step counter = 103
# -------------------------------------------------------------------
# Step counter = 104
# -------------------------------------------------------------------
# Step counter = 105
# -------------------------------------------------------------------
# Step counter = 106
# -------------------------------------------------------------------
# Step counter = 107
# -------------------------------------------------------------------
# Step counter = 108
# -------------------------------------------------------------------
# Step counter = 109
# -------------------------------------------------------------------
# Step counter = 110
# -------------------------------------------------------------------
# Step counter = 111
# -------------------------------------------------------------------
# Step counter = 112
# -------------------------------------------------------------------
# Step counter = 113
# -------------------------------------------------------------------
# Step counter = 114
# -------------------------------------------------------------------
# Step counter = 115
# -------------------------------------------------------------------
# Step counter = 116
# -------------------------------------------------------------------
# Step counter = 117
# -------------------------------------------------------------------
# Step counter = 118
# -------------------------------------------------------------------
# Step counter = 119
# -------------------------------------------------------------------
# Step counter = 120
# -------------------------------------------------------------------
# Step counter = 121
# -------------------------------------------------------------------
# Step counter = 122
# -------------------------------------------------------------------
# Step counter = 123
# -------------------------------------------------------------------
# Step counter = 124
# -------------------------------------------------------------------
# Step counter = 125
# -------------------------------------------------------------------
# Step counter = 126
# -------------------------------------------------------------------
# Step counter = 127
# -------------------------------------------------------------------
# Step counter = 128
# -------------------------------------------------------------------
# Step counter = 129
# -------------------------------------------------------------------
# Step counter = 130
# -------------------------------------------------------------------
# Step counter = 131
# -------------------------------------------------------------------
# Step counter = 132
# -------------------------------------------------------------------
# Step counter = 133
# -------------------------------------------------------------------
# Step counter = 134
# -------------------------------------------------------------------
# Step counter = 135
# -------------------------------------------------------------------
# Step counter = 136
# -------------------------------------------------------------------
# Step counter = 137
# -------------------------------------------------------------------
# Step counter = 138
# -------------------------------------------------------------------
# Step counter = 139
# -------------------------------------------------------------------
# Step counter = 140
# -------------------------------------------------------------------
# Step counter = 141
# -------------------------------------------------------------------
# Step counter = 142
# -------------------------------------------------------------------
# Step counter = 143
# -------------------------------------------------------------------
# Step counter = 144
# -------------------------------------------------------------------
# Step counter = 145
# -------------------------------------------------------------------
# Step counter = 146
# -------------------------------------------------------------------
# Step counter = 147
# -------------------------------------------------------------------
# Step counter = 148
# -------------------------------------------------------------------
# Step counter = 149
# -------------------------------------------------------------------
# Step counter = 150
# -------------------------------------------------------------------
# Step counter = 151
# -------------------------------------------------------------------
# Step counter = 152
# -------------------------------------------------------------------
# Step counter = 153
# -------------------------------------------------------------------
# Step counter = 154
# -------------------------------------------------------------------
# Step counter = 155
# -------------------------------------------------------------------
# Step counter = 156
# -------------------------------------------------------------------
# Step counter = 157
# -------------------------------------------------------------------
# Step counter = 158
# -------------------------------------------------------------------
# Step counter = 159
# -------------------------------------------------------------------
# Step counter = 160
# -------------------------------------------------------------------
# Step counter = 161
# -------------------------------------------------------------------
# Step counter = 162
# -------------------------------------------------------------------
# Step counter = 163
# -------------------------------------------------------------------
# Step counter = 164
# -------------------------------------------------------------------
# Step counter = 165
# -------------------------------------------------------------------
# Step counter = 166
# -------------------------------------------------------------------
# Step counter = 167
# -------------------------------------------------------------------
# Step counter = 168
# -------------------------------------------------------------------
# Step counter = 169
# -------------------------------------------------------------------
# Step counter = 170
# -------------------------------------------------------------------
# Step counter = 171
# -------------------------------------------------------------------
# Step counter = 172
# -------------------------------------------------------------------
# Step counter = 173
# -------------------------------------------------------------------
# Step counter = 174
# -------------------------------------------------------------------
# Step counter = 175
# -------------------------------------------------------------------
# Step counter = 176
# -------------------------------------------------------------------
# Step counter = 177
# -------------------------------------------------------------------
# Step counter = 178
# -------------------------------------------------------------------
# Step counter = 179
# -------------------------------------------------------------------
# Step counter = 180
# -------------------------------------------------------------------
# Step counter = 181
# -------------------------------------------------------------------
# Step counter = 182
# -------------------------------------------------------------------
# Step counter = 183
# -------------------------------------------------------------------
# Step counter = 184
# -------------------------------------------------------------------
# Step counter = 185
# -------------------------------------------------------------------
# Step counter = 186
# -------------------------------------------------------------------
# Step counter = 187
# -------------------------------------------------------------------
# Step counter = 188
# -------------------------------------------------------------------
# Step counter = 189
# -------------------------------------------------------------------
# Step counter = 190
# -------------------------------------------------------------------
# Step counter = 191
# -------------------------------------------------------------------
# Step counter = 192
# -------------------------------------------------------------------
# Step counter = 193
# -------------------------------------------------------------------
# Step counter = 194
# -------------------------------------------------------------------
# Step counter = 195
# -------------------------------------------------------------------
# Step counter = 196
# -------------------------------------------------------------------
# Step counter = 197
# -------------------------------------------------------------------
# Step counter = 198
# -------------------------------------------------------------------
# Step counter = 199
# -------------------------------------------------------------------
# Step counter = 200
# -------------------------------------------------------------------
# Step counter = 201
# -------------------------------------------------------------------
# Step counter = 202
# -------------------------------------------------------------------
# Step counter = 203
# -------------------------------------------------------------------
# Step counter = 204
# -------------------------------------------------------------------
# Step counter = 205
# -------------------------------------------------------------------
# Step counter = 206
# -------------------------------------------------------------------
# Step counter = 207
# -------------------------------------------------------------------
# Step counter = 208
# -------------------------------------------------------------------
# Step counter = 209
# -------------------------------------------------------------------
# Step counter = 210
# -------------------------------------------------------------------
# Step counter = 211
# -------------------------------------------------------------------
# Step counter = 212
# -------------------------------------------------------------------
# Step counter = 213
# -------------------------------------------------------------------
# Step counter = 214
# -------------------------------------------------------------------
# Step counter = 215
# -------------------------------------------------------------------
# Step counter = 216
# -------------------------------------------------------------------
# Step counter = 217
# -------------------------------------------------------------------
# Step counter = 218
# -------------------------------------------------------------------
# Step counter = 219
# -------------------------------------------------------------------
# Step counter = 220
# -------------------------------------------------------------------
# Step counter = 221
# -------------------------------------------------------------------
# Step counter = 222
# -------------------------------------------------------------------
# Step counter = 223
# -------------------------------------------------------------------
# Step counter = 224
# -------------------------------------------------------------------
# Step counter = 225
# -------------------------------------------------------------------
# Step counter = 226
# -------------------------------------------------------------------
# Step counter = 227
# -------------------------------------------------------------------
# Step counter = 228
# -------------------------------------------------------------------
# Step counter = 229
# -------------------------------------------------------------------
# Step counter = 230
# -------------------------------------------------------------------
# Step counter = 231
# -------------------------------------------------------------------
# Step counter = 232
# -------------------------------------------------------------------
# Step counter = 233
# -------------------------------------------------------------------
# Step counter = 234
# -------------------------------------------------------------------
# Step counter = 235
# -------------------------------------------------------------------
# Step counter = 236
# -------------------------------------------------------------------
# Step counter = 237
# -------------------------------------------------------------------
# Step counter = 238
# -------------------------------------------------------------------
# Step counter = 239
# -------------------------------------------------------------------
# Step counter = 240
# -------------------------------------------------------------------
# Step counter = 241
# -------------------------------------------------------------------
# Step counter = 242
# -------------------------------------------------------------------
# Step counter = 243
# -------------------------------------------------------------------
# Step counter = 244
# -------------------------------------------------------------------
# Step counter = 245
# -------------------------------------------------------------------
# Step counter = 246
# -------------------------------------------------------------------
# Step counter = 247
# -------------------------------------------------------------------
# Step counter = 248
# -------------------------------------------------------------------
# Step counter = 249
# -------------------------------------------------------------------
# Step counter = 250
# -------------------------------------------------------------------
# Step counter = 251
# -------------------------------------------------------------------
# Step counter = 252
# -------------------------------------------------------------------
# Step counter = 253
# -------------------------------------------------------------------
# Step counter = 254
# -------------------------------------------------------------------
# Step counter = 255
# -------------------------------------------------------------------
# Step counter = 256
# -------------------------------------------------------------------
# Step counter = 257
# -------------------------------------------------------------------
# Step counter = 258
# -------------------------------------------------------------------
# Step counter = 259
# -------------------------------------------------------------------
# Step counter = 260
# -------------------------------------------------------------------
# Step counter = 261
# -------------------------------------------------------------------
# Step counter = 262
# -------------------------------------------------------------------
# Step counter = 263
# -------------------------------------------------------------------
# Step counter = 264
# -------------------------------------------------------------------
# Step counter = 265
# -------------------------------------------------------------------
# Step counter = 266
# -------------------------------------------------------------------
# Step counter = 267
# -------------------------------------------------------------------
# Step counter = 268
# -------------------------------------------------------------------
# Step counter = 269
# -------------------------------------------------------------------
# Step counter = 270
# -------------------------------------------------------------------
# Step counter = 271
# -------------------------------------------------------------------
# Step counter = 272
# -------------------------------------------------------------------
# Step counter = 273
# -------------------------------------------------------------------
# Step counter = 274
# -------------------------------------------------------------------
# Step counter = 275
# -------------------------------------------------------------------
# Step counter = 276
# -------------------------------------------------------------------
# Step counter = 277
# -------------------------------------------------------------------
# Step counter = 278
# -------------------------------------------------------------------
# Step counter = 279
# -------------------------------------------------------------------
# Step counter = 280
# -------------------------------------------------------------------
# Step counter = 281
# -------------------------------------------------------------------
# Step counter = 282
# -------------------------------------------------------------------
# Step counter = 283
# -------------------------------------------------------------------
# Step counter = 284
# -------------------------------------------------------------------
# Step counter = 285
# -------------------------------------------------------------------
# Step counter = 286
# -------------------------------------------------------------------
# Step counter = 287
# -------------------------------------------------------------------
# Step counter = 288

# %%
def get_and_plot_results(testid, start_time, final_time):
    points = ['zon_reaTRooAir_y', 'fcu_oveTSup_u', 'fcu_oveFan_u', 'zon_weaSta_reaWeaTDryBul_y']
    args = {
        'point_names': points,
        'start_time': start_time, 
        'final_time': final_time
    }
    
    response = requests.put('{0}/results/{1}'.format(url, testid), json=args).json()
    
    if 'payload' not in response:
        print("Error: Could not retrieve data. Check if testid is still active.")
        return None
        
    df_res = pd.DataFrame(data=response['payload'])
    
    df_res = df_res.set_index('time')
    x_time = df_res.index / 3600. / 24.
    x_time = x_time - (start_time / 3600. / 24.)
    df_res['time'] = x_time
    

    plt.close('all')
    fig, axs = plt.subplots(4, 1, sharex=True, figsize=(10, 10))
    
    axs[0].plot(x_time, df_res['zon_reaTRooAir_y'] - 273.15, color='darkorange', linewidth=0.8, label='$T_z$')
    axs[0].set_ylabel('Operative\nTemp ($^\circ$C)')
    axs[0].legend(loc='upper right')
    axs[0].grid(True)

    axs[1].plot(x_time, df_res['zon_weaSta_reaWeaTDryBul_y'] - 273.15, color='green', linewidth=0.8, label='$T_{amb}$')
    axs[1].set_ylabel('Ambient\nTemp ($^\circ$C)')
    axs[1].legend(loc='upper right')
    axs[1].grid(True)

    axs[2].plot(x_time, df_res['fcu_oveTSup_u'] - 273.15, color='red', linewidth=0.8, label='$fcu_oveTSup_u$')
    axs[2].legend(loc='upper right')
    axs[2].grid(True)

    axs[3].plot(x_time, df_res['fcu_oveFan_u'], color='royalblue', linewidth=0.8, label='$fcu_oveFan_u$')
    axs[3].set_xlabel('Time (days)')
    axs[3].legend(loc='upper right')
    axs[3].grid(True)

    plt.tight_layout()
    plt.show()
    
    return df_res

start_in_seconds = start_time_days * 24 * 3600
final_in_seconds = start_in_seconds + (14 * 24 * 3600)

get_and_plot_results(testid=testid, start_time=start_in_seconds, final_time=final_in_seconds)
# Out:
#          zon_reaTRooAir_y  fcu_oveTSup_u  fcu_oveFan_u  \
# time
# 3801600        295.310128     294.150000      0.000000
# 3801630        295.222125     293.150000      0.500000
# 3801660        295.117210     293.150000      0.500000
# 3801690        295.023884     293.150000      0.500000
# 3801720        294.940950     293.150000      0.500000
# ...                   ...            ...           ...
# 3888480        305.947919     312.162354      0.931636
# 3888510        305.935371     312.162354      0.931636
# 3888540        305.924976     312.162354      0.931636
# 3888570        305.916334     312.162354      0.931636
# 3888600        305.909133     312.162354      0.931636
#
#          zon_weaSta_reaWeaTDryBul_y      time
# time
# 3801600                  279.050000  0.000000
# 3801630                  279.025812  0.000347
# 3801660                  279.001625  0.000694
# 3801690                  278.977439  0.001042
# 3801720                  278.953254  0.001389
# ...                             ...       ...
# 3888480                  268.916667  1.005556
# 3888510                  268.908333  1.005903
# 3888540                  268.900000  1.006250
# 3888570                  268.891667  1.006597
# 3888600                  268.883333  1.006944
#
# [2901 rows x 5 columns]

# %%
ls_rmse = [r.item()*30 for r in ls_rmse]    
plt.plot(ls_rmse)
plt.xlabel('Iteration (number of new data points)')
plt.grid()
plt.ylabel('RMSE (F)')
plt.title(f'Active learning RMSE (ini = {Ne_tr} points)')
plt.show()
import os
save_dir = 'results'
os.makedirs(save_dir, exist_ok=True)

df = pd.DataFrame(np.array(ls_rmse), columns=["RMSE_MCD_NN"])

save_path = f"RMSE_MCD_NN_ini{Ne_tr}_lr{const.lr}_ramp{const.ramp}.csv"                   
full_path = os.path.join(save_dir, save_path)               
df.to_csv(full_path, index=False)

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
